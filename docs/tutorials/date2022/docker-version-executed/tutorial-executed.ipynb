# %% [markdown]
# # SODA Toolchain
#
# ![tutorial-flow](imgs/flow-diagram.png)

# %% [markdown]
# # High-Level Application Input (TensorFlow)

# %% [markdown]
# ### Build a model in tensorflow (Step 1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
import numpy as np
tf.random.set_seed(seed=0)
print(tf.__version__)

in1 = keras.layers.Input(shape=(32,32,1))
tmp = keras.layers.Conv2D(filters=1, kernel_size=(5,5),
                          input_shape=(32,32),
                          padding='same', 
                          strides=(2, 2),
                          activation='relu', 
                          use_bias=True)(in1)
tmp = keras.layers.Flatten()(tmp)
tmp = keras.layers.Dense(units=8, activation='relu')(tmp)
tmp = keras.layers.Dense(units=4, activation='relu')(tmp)
out = keras.layers.Dense(units=2, activation='softmax')(tmp)
model = keras.models.Model(inputs=[in1], outputs=out)

# Compile model with optimizer
model.compile(optimizer="adam",
                loss="sparse_categorical_crossentropy",
                metrics=["accuracy"])
# Out:
# 2.4.1
# 2022-03-21 03:47:53.383003: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-21 03:47:53.383311: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-21 03:47:53.386788: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# ### Convert model to protobuf

# %%
# !mkdir -p output

# %%
save_path = os.path.join(os.getcwd(), "model/simple/")

# Save model to SavedModel format
tf.saved_model.save(model, save_path)

# Convert Keras model to ConcreteFunction
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    x=[
        tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype, name='x1')
    ])

# Get frozen ConcreteFunction
frozen_func = convert_variables_to_constants_v2(full_model)

# Save frozen graph from frozen ConcreteFunction to hard drive
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                    logdir=os.getcwd(),
                    name="output/frozen_graph.pbtxt",
                    as_text=True)
# Out:
# 2022-03-21 03:48:05.765390: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version/model/simple/assets
# 2022-03-21 03:48:06.073309: I tensorflow/core/grappler/devices.cc:78] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2022-03-21 03:48:06.073522: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2022-03-21 03:48:06.093406: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2795020000 Hz
# 2022-03-21 03:48:06.096859: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:928] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: function_optimizer did nothing. time = 0.005ms.
#   function_optimizer: function_optimizer did nothing. time = 0ms.
# '/files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version/output/frozen_graph.pbtxt'

# %% [markdown]
# ![tutorial-flow](imgs/flow-diagram.png)

# %% [markdown]
# ### Transform protobuf into MLIR (Step 2)

# %%
# !scripts/protobuf-to-tosa.sh output/frozen_graph.pbtxt output/tosa.mlir
# Out:
# 2022-03-21 10:48:31.718652: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Lower MLIR to Linalg on Buffers (Step 3)

# %%
# !scripts/tosa-to-linalg.sh output/tosa.mlir output/linalg-buffers.mlir

# %% [markdown]
# ![tutorial-flow](imgs/flow-diagram.png)

# %% [markdown]
# # SODA-OPT: HW/SW Partitioning and Optimizer (Step 4)

# %% [markdown]
# ## How to use soda.launch?
#
# ### Automatic selection of custom accelerator region
#
# Using the pass: `-convert-<abstraction_name>-<operation_name>-to-soda`
#
# Such as: `-convert-linalg-generic-to-soda`

# %% [markdown]
# ### Manual selection of custom accelerator region

# %% [markdown]
# Adding the following lines around any code that will become the accelerator:
#
# ```
# soda.launch {
#   // ...
#   // Code to be transformed into an accelerator
#   // ...
#   soda.terminator
# }
# ```
#
# Run next cell and edit [file](output/01searched-edited.mlir).

# %%
# !cp output/linalg-buffers.mlir output/01searched-edited.mlir

# Perform manual edit!

# %% [markdown]
# Edit the [file](output/01searched-edited.mlir).

# %% [markdown]
# ## Optimization pipeline
#
# ![optimizations](imgs/optimization-table.png)
#
# ### Kernel without SODA-OPT optimizations (Baseline)

# %%
# %%bash
# (
#   docker run -u $(id -u) -v $(pwd):/working_dir --rm agostini01/soda \
#   soda-opt \
#     -soda-outline-bambu-code \
#     -soda-extract-arguments-to-xml=using-bare-ptr \
#     -soda-generate-bambu-accelcode=no-aa \
#     -lower-all-to-llvm=use-bare-ptr-memref-call-conv \
#     -print-ir-after-all \
#     output/01searched-edited.mlir \
#     -o output/04baseline.mlir \
#     2>&1 | cat > output/05intermediate-baseline.mlir
#
#   docker run -u $(id -u) -v $(pwd):/working_dir --rm agostini01/soda \
#   mlir-translate \
#     --mlir-to-llvmir \
#     output/04baseline.mlir \
#     -o output/05baseline.ll
# )

# %% [markdown]
# Visualize [intermediate file](output/05intermediate-baseline.mlir)

# %% [markdown]
# ### Kernel with SODA-OPT optimizations

# %%
# %%bash
# (
#   docker run -u $(id -u) -v $(pwd):/working_dir --rm agostini01/soda \
#   soda-opt \
#     -soda-outline-bambu-code \
#     -soda-extract-arguments-to-xml=using-bare-ptr \
#     -soda-generate-bambu-accelcode \
#     -soda-opt-pipeline-for-bambu=use-bare-ptr-memref-call-conv \
#     -print-ir-after-all \
#     output/01searched-edited.mlir \
#     -o output/04optimized.mlir \
#     2>&1 | cat > output/05intermediate-optimized.mlir
#
#   docker run -u $(id -u) -v $(pwd):/working_dir --rm agostini01/soda \
#   mlir-translate \
#     --mlir-to-llvmir \
#     output/04optimized.mlir \
#     -o output/05optimized.ll
# )

# %% [markdown]
# Visualize [intermediate file](output/05intermediate-optimized.mlir)

# %% [markdown]
# ![tutorial-flow](imgs/flow-diagram.png)

# %% [markdown]
# # Bambu: Synthesizing the Outlined Kernel (Step 5)

# %% [markdown]
# The following configurations are passed to our backend HLS tool:
#
# * Target: ASIC generation using the Nangate cell library with the FreePDK 45nm kit
# * Memory technology: SRAM
# * Number of memory channels: 2
#   * Supports 2 parallel reads and 2 parallel writes
# * Target frequency: 200MHz (5ns period)
# * Using bambu's floating-point operation support

# %% [markdown]
# ### Baseline kernel

# %%
! scripts/run-bambu.sh baseline
# Out:
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version/output/baseline /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version
#  ==  Bambu executed with: bambu -v3 --print-dot -lm --soft-float --compiler=I386_CLANG10 -O2 --device=nangate45 --clock-period=5 --no-iob --experimental-setup=BAMBU-BALANCED-MP --channels-number=2 --memory-allocation-policy=ALL_BRAM --disable-function-proxy --generate-tb=main_kernel_test.xml --simulate --simulator=VERILATOR --top-fname=main_kernel input.ll
#
#
# ********************************************************************************
#                     ____                  _
#                    | __ )  __ _ _ __ ___ | |_   _   _
#                    |  _ \ / _` | '_ ` _ \| '_ \| | | |
#                    | |_) | (_| | | | | | | |_) | |_| |
#                    |____/ \__,_|_| |_| |_|_.__/ \__,_|
#
# ********************************************************************************
#                          High-Level Synthesis Tool
#
#                          Politecnico di Milano - DEIB
#                           System Architectures Group
# ********************************************************************************
#                 Copyright (C) 2004-2021 Politecnico di Milano
#   Version: PandA 0.9.7-dev - Revision 891ec3caed502474cab0813cc4a9fc678deabaa5
#
# Parameters parsed in 0.14 seconds
#
# Target technology = FPGA
# Library Name     : STD_FU
#   Total cells    : 3
#   - combinational: 0
#   - others: 3
#
# Library Name     : STD_FU
#   Total cells    : 10
#   - combinational: 0
#   - others: 10
#
# Library Name     : STD_FU
#   Total cells    : 31
#   - combinational: 0
#   - others: 31
#
# Library Name     : STD_FU
#   Total cells    : 8
#   - combinational: 0
#   - others: 8
#
# Library Name     : STD_FU
#   Total cells    : 56
#   - combinational: 0
#   - others: 56
#
# Library Name     : STD_FU
#   Total cells    : 1
#   - combinational: 0
#   - others: 1
#
# Library Name     : CS_COMPONENT
#   Total cells    : 16
#   - combinational: 0
#   - others: 16
#
# Library Name     : STD_FU
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD_FU
#   Total cells    : 0
#   - combinational: 0
#   - others: 0
#
# Library Name     : STD_FU
#   Total cells    : 0
#   - combinational: 0
#   - others: 0
#
# Library Name     : STD_FU
#   Total cells    : 17
#   - combinational: 0
#   - others: 17
#
# Library Name     : STD
#   Total cells    : 14
#   - combinational: 0
#   - others: 14
#
# Library Name     : STD_COMMON
#   Total cells    : 57
#   - combinational: 0
#   - others: 57
#
# Library Name     : STD_FU
#   Total cells    : 8
#   - combinational: 0
#   - others: 8
#
# Library Name     : STD_PC
#   Total cells    : 16
#   - combinational: 0
#   - others: 16
#
# Library Name     : STD_SOFT_FLOAT
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD
#   Total cells    : 72
#   - combinational: 0
#   - others: 72
#
# Library Name     : STD_FU
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD_FU
#   Total cells    : 4
#   - combinational: 0
#   - others: 4
#
# Library Name     : WBWrapper
#   Total cells    : 12
#   - combinational: 0
#   - others: 12
#
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
#  (in-process)  /usr/local/include  /usr/lib/llvm-10/lib/clang/10.0.0/include  /usr/include/x86_64-linux-gnu  /usr/include  warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
#
# Available devices:
#  - 5CSEMA5F31C6
#  - 5SGXEA7N2F45C1
#  - EP2C70F896C6
#  - EP2C70F896C6-R
#  - EP4SGX530KH40C2
#  - LFE335EA8FN484C
#  - LFE5U85F8BG756C
#  - LFE5UM85F8BG756C
#  - nangate45
#  - nx1h140tsp
#  - nx1h35S
#  - xc4vlx100-10ff1513
#  - xc5vlx110t-1ff1136
#  - xc5vlx330t-2ff1738
#  - xc5vlx50-3ff1153
#  - xc6vlx240t-1ff1156
#  - xc7a100t-1csg324-VVD
#  - xc7vx330t-1ffg1157
#  - xc7vx485t-2ffg1761-VVD
#  - xc7vx690t-3ffg1930-VVD
#  - xc7z020-1clg484
#  - xc7z020-1clg484-VVD
#  - xc7z020-1clg484-YOSYS-VVD
#  - xc7z045-2ffg900-VVD
# Library Name     : STD_FU
#   Total cells    : 4303
#   - combinational: 0
#   - others: 4303
#
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: minus_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 3
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 3
#   Bit Value Opt: cond_expr optimized, nbits = 4
#   Bit Value Opt: cond_expr optimized, nbits = 5
#   Bit Value Opt: bit_xor_expr optimized, nbits = 2
#   Bit Value Opt: bit_and_expr optimized, nbits = 2
#   Bit Value Opt: ne_expr optimized, nbits = 2
#   Bit Value Opt: plus_expr optimized, nbits = 2
#   Bit Value Opt: bit_and_expr optimized, nbits = 11
#   Bit Value Opt: eq_expr optimized, nbits = 11
#   Bit Value Opt: bit_and_expr optimized, nbits = 19
#   Bit Value Opt: eq_expr optimized, nbits = 19
#   Bit Value Opt: bit_and_expr optimized, nbits = 23
#   Bit Value Opt: eq_expr optimized, nbits = 23
#   Bit Value Opt: bit_and_expr optimized, nbits = 25
#   Bit Value Opt: eq_expr optimized, nbits = 25
#   Bit Value Opt: bit_and_expr optimized, nbits = 26
#   Bit Value Opt: eq_expr optimized, nbits = 26
#   Bit Value Opt: bit_and_expr optimized, nbits = 26
#   Bit Value Opt: ne_expr optimized, nbits = 26
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: bit_and_expr optimized, nbits = 1
#   Bit Value Opt: ne_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: bit_and_expr optimized, nbits = 22
#   Bit Value Opt: ne_expr optimized, nbits = 22
#   Bit Value Opt: bit_and_expr optimized, nbits = 47
#   Bit Value Opt: ne_expr optimized, nbits = 47
#   Bit Value Opt: bit_and_expr optimized, nbits = 9
#   Bit Value Opt: ne_expr optimized, nbits = 9
#   Bit Value Opt: bit_and_expr optimized, nbits = 24
#   Bit Value Opt: ne_expr optimized, nbits = 24
#   Bit Value Opt: plus_expr optimized, nbits = 2
#   Bit Value Opt: plus_expr optimized, nbits = 2
#   Bit Value Opt: plus_expr optimized, nbits = 3
#   Bit Value Opt: plus_expr optimized, nbits = 2
#   Bit Value Opt: plus_expr optimized, nbits = 4
#   Bit Value Opt: plus_expr optimized, nbits = 2
#   Bit Value Opt: plus_expr optimized, nbits = 3
#   Bit Value Opt: plus_expr optimized, nbits = 2
#
#   Memory allocation information:
# Warning: This function uses unknown addresses: main_kernel
#     BRAM bitsize: 16
#     Spec may not exploit DATA bus width
#     Spec accesses data having an address unknown at compile time
#     Internal data is not externally accessible
#     DATA bus bitsize: 32
#     ADDRESS bus bitsize: 32
#     SIZE bus bitsize: 6
#     Internally allocated memory (no private memories): 0
#     Internally allocated memory: 0
#   Time to perform memory allocation: 0.00 seconds
#
#
#   Module allocation information for function __float_adde8m23b_127rnh:
#     Number of complex operations: 0
#     Number of complex operations: 0
#   Time to perform module allocation: 0.09 seconds
#
#
#   Module allocation information for function __float_mule8m23b_127rnh:
#     Number of complex operations: 0
#     Number of complex operations: 0
#   Time to perform module allocation: 0.06 seconds
#
#
#   Scheduling Information of function __float_adde8m23b_127rnh:
#     Number of control steps: 4
#     Minimum slack: 0.051269958999998477
#     Estimated max frequency (MHz): 202.07204509339684
#   Time to perform scheduling: 0.04 seconds
#
#   Number of function call sites = 8
#
#   State Transition Graph Information of function __float_adde8m23b_127rnh:
#     Number of operations: 282
#     Number of basic blocks: 3
#     Number of states: 3
#     Minimum number of cycles: 3
#     Maximum number of cycles 3
#     Parameters are registered
#     Done port is registered
#   Time to perform creation of STG: 0.05 seconds
#
#
#   Scheduling Information of function __float_mule8m23b_127rnh:
#     Number of control steps: 4
#     Minimum slack: 0.087999980999997118
#     Estimated max frequency (MHz): 203.58306110177548
#   Time to perform scheduling: 0.03 seconds
#
#   Number of function call sites = 8
#
#   State Transition Graph Information of function __float_mule8m23b_127rnh:
#     Number of operations: 223
#     Number of basic blocks: 3
#     Number of states: 3
#     Minimum number of cycles: 3
#     Maximum number of cycles 3
#     Parameters are registered
#     Done port is registered
#   Time to perform creation of STG: 0.03 seconds
#
#
#   Easy binding information for function __float_adde8m23b_127rnh:
#     Bound operations:115/282
#   Time to perform easy binding: 0.00 seconds
#
#
#   Easy binding information for function __float_mule8m23b_127rnh:
#     Bound operations:102/223
#   Time to perform easy binding: 0.00 seconds
#
#
#   Storage Value Information of function __float_adde8m23b_127rnh:
#     Number of storage values inserted: 15
#   Time to compute storage value information: 0.00 seconds
#
#
#   Storage Value Information of function __float_mule8m23b_127rnh:
#     Number of storage values inserted: 8
#   Time to compute storage value information: 0.00 seconds
#
#
#   Register binding information for function __float_adde8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 15 registers
#   Time to perform register binding: 0.00 seconds
#
#
#   Module binding information for function __float_adde8m23b_127rnh:
#     Number of modules instantiated: 282
#     Number of possible conflicts for possible false paths introduced by resource sharing: 259
#     Estimated resources area (no Muxes and address logic): 193068
#     Estimated area of MUX21: 0
#     Total estimated area: 193068
#     Estimated number of DSPs: 0
#     Slack computed in 0.00 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.00 seconds
#     Clique covering computation:
#       Iteration 0 completed in 0.00 seconds
#       Iteration 1 completed in 0.00 seconds
#   Time to perform module binding: 0.01 seconds
#
#
#   Register binding information for function __float_adde8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 15 registers
#   Time to perform register binding: 0.00 seconds
#
#   Total number of flip-flops in function __float_adde8m23b_127rnh: 165
#   All registers are without enable: function pipelining may come for free
#   Resources are not shared in function __float_adde8m23b_127rnh: function pipelining may come for free
#
#   Register binding information for function __float_mule8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 8 registers
#   Time to perform register binding: 0.00 seconds
#
#
#   Module binding information for function __float_mule8m23b_127rnh:
#     Number of modules instantiated: 223
#     Number of possible conflicts for possible false paths introduced by resource sharing: 6
#     Estimated resources area (no Muxes and address logic): 118284
#     Estimated area of MUX21: 0
#     Total estimated area: 118284
#     Estimated number of DSPs: 0
#     Slack computed in 0.00 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.00 seconds
#     Clique covering computation:
#       Iteration 0 completed in 0.00 seconds
#       Iteration 1 completed in 0.00 seconds
#   Time to perform module binding: 0.01 seconds
#
#
#   Register binding information for function __float_mule8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 8 registers
#   Time to perform register binding: 0.00 seconds
#
#   Total number of flip-flops in function __float_mule8m23b_127rnh: 103
#   All registers are without enable: function pipelining may come for free
#   Resources are not shared in function __float_mule8m23b_127rnh: function pipelining may come for free
#
#   Module allocation information for function main_kernel:
#     Number of complex operations: 41
#     Number of complex operations: 41
#   Time to perform module allocation: 0.04 seconds
#
#
#   Scheduling Information of function main_kernel:
#     Number of control steps: 77
#     Minimum slack: 0.051269956999985877
#     Estimated max frequency (MHz): 202.0720450117301
#   Time to perform scheduling: 0.03 seconds
#
#   Number of function call sites = 0
#
#   State Transition Graph Information of function main_kernel:
#     Number of operations: 195
#     Number of basic blocks: 6
#     Number of states: 75
#     Done port is registered
#   Time to perform creation of STG: 0.07 seconds
#
#
#   Easy binding information for function main_kernel:
#     Bound operations:95/195
#   Time to perform easy binding: 0.00 seconds
#
#
#   Storage Value Information of function main_kernel:
#     Number of storage values inserted: 67
#   Time to compute storage value information: 0.00 seconds
#
#   cdfc mux estimation 22 -- Number of cliques covering the graph: 2 main_kernel_BMEMORY_CTRLN_68 with 25 vertices
#   cdfc mux estimation 14 -- Number of cliques covering the graph: 1 main_kernel___float_adde8m23b_127rnh_106 with 8 vertices
#   cdfc mux estimation 14 -- Number of cliques covering the graph: 1 main_kernel___float_mule8m23b_127rnh_107 with 8 vertices
#
#   Register binding information for function main_kernel:
#     Register allocation algorithm obtains a sub-optimal result: 65 registers(LB:28)
#   Time to perform register binding: 0.01 seconds
#
#   cdfc mux estimation 22 -- Number of cliques covering the graph: 2 main_kernel_BMEMORY_CTRLN_68 with 25 vertices
#   cdfc mux estimation 14 -- Number of cliques covering the graph: 1 main_kernel___float_adde8m23b_127rnh_106 with 8 vertices
#   cdfc mux estimation 14 -- Number of cliques covering the graph: 1 main_kernel___float_mule8m23b_127rnh_107 with 8 vertices
#
#   Module binding information for function main_kernel:
#     Number of modules instantiated: 158
#     Number of possible conflicts for possible false paths introduced by resource sharing: 0
#     Estimated resources area (no Muxes and address logic): 152965
#     Estimated area of MUX21: 112292
#     Total estimated area: 265257
#     Estimated number of DSPs: 0
#     Slack computed in 0.01 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.00 seconds
#     Clique covering computation:
#       Iteration 0 completed in 0.00 seconds
#       Iteration 1 completed in 0.00 seconds
#   Time to perform module binding: 0.02 seconds
#
#
#   Register binding information for function main_kernel:
#     Register allocation algorithm obtains a sub-optimal result: 65 registers(LB:28)
#   Time to perform register binding: 0.00 seconds
#
#
#   Connection Binding Information for function main_kernel:
#     Number of allocated multiplexers (2-to-1 equivalent): 52
#     Total number of bit-level multiplexers: 1728
#   Time to perform interconnection binding: 0.01 seconds
#
#   Total number of flip-flops in function main_kernel: 2047
#  .:: Creating Generic Bash Backend Flow ::.
#   Parameter P0 (494024) (testvector 0) allocated at 1073741824 : reserved_mem_size = 128
#   Parameter P1 (494025) (testvector 0) allocated at 1073741952 : reserved_mem_size = 128
#   Parameter P2 (494026) (testvector 0) allocated at 1073742080 : reserved_mem_size = 64
#   C-based testbench generation for function main_kernel: /working_dir/HLS_output//simulation/values.c
#   Prepared testbench
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
#
#   Summary of resources:
#      - ASSIGN_UNSIGNED_FU: 3
#      - ASSIGN_VECTOR_BOOL_FU: 8
#      - BMEMORY_CTRLN: 1
#      - IIdata_converter_FU: 2
#      - IUdata_converter_FU: 8
#      - MUX_GATE: 52
#      - OR_GATE: 2
#      - UIdata_converter_FU: 8
#      - UUdata_converter_FU: 163
#      - bus_merger: 5
#      - constant_value: 59
#      - flipflop_AR: 2
#      - join_signal: 5
#      - lshift_expr_FU: 2
#      - multi_read_cond_FU: 1
#      - register_SE: 57
#      - register_STD: 35
#      - rshift_expr_FU: 8
#      - split_signal: 5
#      - truth_and_expr_FU: 65
#      - truth_not_expr_FU: 2
#      - truth_or_expr_FU: 11
#      - truth_xor_expr_FU: 4
#      - ui_bit_and_expr_FU: 82
#      - ui_bit_ior_concat_expr_FU: 9
#      - ui_bit_ior_expr_FU: 47
#      - ui_bit_xor_expr_FU: 16
#      - ui_cond_expr_FU: 36
#      - ui_eq_expr_FU: 26
#      - ui_extract_bit_expr_FU: 8
#      - ui_lshift_expr_FU: 74
#      - ui_lt_expr_FU: 4
#      - ui_minus_expr_FU: 1
#      - ui_mult_expr_FU: 1
#      - ui_ne_expr_FU: 17
#      - ui_plus_expr_FU: 15
#      - ui_pointer_plus_expr_FU: 17
#      - ui_rshift_expr_FU: 53
#      - ui_ternary_plus_expr_FU: 1
#      - ui_ternary_pm_expr_FU: 1
# make: Entering directory '/working_dir/HLS_output/verilator_beh/verilator_obj'
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o testbench_main_kernel_main.o /working_dir/HLS_output//simulation/testbench_main_kernel_main.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o verilated.o /usr/share/verilator/include/verilated.cpp
# /usr/bin/perl /usr/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include Vmain_kernel_tb.cpp > Vmain_kernel_tb__ALLcls.cpp
# /usr/bin/perl /usr/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include Vmain_kernel_tb__Syms.cpp > Vmain_kernel_tb__ALLsup.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o Vmain_kernel_tb__ALLsup.o Vmain_kernel_tb__ALLsup.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o Vmain_kernel_tb__ALLcls.o Vmain_kernel_tb__ALLcls.cpp
# ar -cr Vmain_kernel_tb__ALL.a Vmain_kernel_tb__ALLcls.o Vmain_kernel_tb__ALLsup.o
# ranlib Vmain_kernel_tb__ALL.a
# g++    testbench_main_kernel_main.o verilated.o Vmain_kernel_tb__ALL.a    -o Vmain_kernel_tb -lm -lstdc++
# make: Leaving directory '/working_dir/HLS_output/verilator_beh/verilator_obj'
# Start reading vector           1's values from input file.
#
# Reading of vector values from input file completed. Simulation started.
# Simulation ended after                 1158 cycles.
#
# Simulation completed with success
#
# - /working_dir/HLS_output//simulation/testbench_main_kernel_tb.v:681: Verilog $finish
# Start reading vector           1's values from input file.
#
# Reading of vector values from input file completed. Simulation started.
# Simulation ended after                 1158 cycles.
#
# Simulation completed with success
#
# - /working_dir/HLS_output//simulation/testbench_main_kernel_tb.v:681: Verilog $finish
# File "/working_dir/results.txt" opened
# 1. Simulation completed with SUCCESS; Execution time 1158 cycles;
#   Total cycles             : 1158 cycles
#   Number of executions     : 1
#   Average execution        : 1158 cycles
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version

# %%
baseline_runtime = ""

for runtime in open('output/baseline/bambu-log').readlines():
    if "Average execution" in runtime:
        baseline_runtime = [int(s) for s in runtime.split() if s.isdigit()][0]

print("Average execution in cycles: {}".format(baseline_runtime))
# Out:
# Average execution in cycles: 1158

# %% [markdown]
# Visualize [Intermediate Dot File](output/baseline/HLS_output/dot/main_kernel/HLS_STGraph.dot)

# %% [markdown]
# ### Optimized kernel

# %%
! scripts/run-bambu.sh optimized
# Takes aprox 30 seconds to execute
# Out:
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version/output/optimized /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version
#  ==  Bambu executed with: bambu -v3 --print-dot -lm --soft-float --compiler=I386_CLANG10 -O2 --device=nangate45 --clock-period=5 --no-iob --experimental-setup=BAMBU-BALANCED-MP --channels-number=2 --memory-allocation-policy=ALL_BRAM --disable-function-proxy --generate-tb=main_kernel_test.xml --simulate --simulator=VERILATOR --top-fname=main_kernel input.ll
#
#
# ********************************************************************************
#                     ____                  _
#                    | __ )  __ _ _ __ ___ | |_   _   _
#                    |  _ \ / _` | '_ ` _ \| '_ \| | | |
#                    | |_) | (_| | | | | | | |_) | |_| |
#                    |____/ \__,_|_| |_| |_|_.__/ \__,_|
#
# ********************************************************************************
#                          High-Level Synthesis Tool
#
#                          Politecnico di Milano - DEIB
#                           System Architectures Group
# ********************************************************************************
#                 Copyright (C) 2004-2021 Politecnico di Milano
#   Version: PandA 0.9.7-dev - Revision 891ec3caed502474cab0813cc4a9fc678deabaa5
#
# Parameters parsed in 0.13 seconds
#
# Target technology = FPGA
# Library Name     : STD_FU
#   Total cells    : 3
#   - combinational: 0
#   - others: 3
#
# Library Name     : STD_FU
#   Total cells    : 10
#   - combinational: 0
#   - others: 10
#
# Library Name     : STD_FU
#   Total cells    : 31
#   - combinational: 0
#   - others: 31
#
# Library Name     : STD_FU
#   Total cells    : 8
#   - combinational: 0
#   - others: 8
#
# Library Name     : STD_FU
#   Total cells    : 56
#   - combinational: 0
#   - others: 56
#
# Library Name     : STD_FU
#   Total cells    : 1
#   - combinational: 0
#   - others: 1
#
# Library Name     : CS_COMPONENT
#   Total cells    : 16
#   - combinational: 0
#   - others: 16
#
# Library Name     : STD_FU
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD_FU
#   Total cells    : 0
#   - combinational: 0
#   - others: 0
#
# Library Name     : STD_FU
#   Total cells    : 0
#   - combinational: 0
#   - others: 0
#
# Library Name     : STD_FU
#   Total cells    : 17
#   - combinational: 0
#   - others: 17
#
# Library Name     : STD
#   Total cells    : 14
#   - combinational: 0
#   - others: 14
#
# Library Name     : STD_COMMON
#   Total cells    : 57
#   - combinational: 0
#   - others: 57
#
# Library Name     : STD_FU
#   Total cells    : 8
#   - combinational: 0
#   - others: 8
#
# Library Name     : STD_PC
#   Total cells    : 16
#   - combinational: 0
#   - others: 16
#
# Library Name     : STD_SOFT_FLOAT
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD
#   Total cells    : 72
#   - combinational: 0
#   - others: 72
#
# Library Name     : STD_FU
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD_FU
#   Total cells    : 4
#   - combinational: 0
#   - others: 4
#
# Library Name     : WBWrapper
#   Total cells    : 12
#   - combinational: 0
#   - others: 12
#
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
#  (in-process)  /usr/local/include  /usr/lib/llvm-10/lib/clang/10.0.0/include  /usr/include/x86_64-linux-gnu  /usr/include
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# Available devices:
#  - 5CSEMA5F31C6
#  - 5SGXEA7N2F45C1
#  - EP2C70F896C6
#  - EP2C70F896C6-R
#  - EP4SGX530KH40C2
#  - LFE335EA8FN484C
#  - LFE5U85F8BG756C
#  - LFE5UM85F8BG756C
#  - nangate45
#  - nx1h140tsp
#  - nx1h35S
#  - xc4vlx100-10ff1513
#  - xc5vlx110t-1ff1136
#  - xc5vlx330t-2ff1738
#  - xc5vlx50-3ff1153
#  - xc6vlx240t-1ff1156
#  - xc7a100t-1csg324-VVD
#  - xc7vx330t-1ffg1157
#  - xc7vx485t-2ffg1761-VVD
#  - xc7vx690t-3ffg1930-VVD
#  - xc7z020-1clg484
#  - xc7z020-1clg484-VVD
#  - xc7z020-1clg484-YOSYS-VVD
#  - xc7z045-2ffg900-VVD
# Library Name     : STD_FU
#   Total cells    : 4303
#   - combinational: 0
#   - others: 4303
#
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: minus_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 3
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 3
#   Bit Value Opt: cond_expr optimized, nbits = 4
#   Bit Value Opt: cond_expr optimized, nbits = 5
#   Bit Value Opt: bit_xor_expr optimized, nbits = 2
#   Bit Value Opt: bit_and_expr optimized, nbits = 2
#   Bit Value Opt: ne_expr optimized, nbits = 2
#   Bit Value Opt: plus_expr optimized, nbits = 2
#   Bit Value Opt: bit_and_expr optimized, nbits = 11
#   Bit Value Opt: eq_expr optimized, nbits = 11
#   Bit Value Opt: bit_and_expr optimized, nbits = 19
#   Bit Value Opt: eq_expr optimized, nbits = 19
#   Bit Value Opt: bit_and_expr optimized, nbits = 23
#   Bit Value Opt: eq_expr optimized, nbits = 23
#   Bit Value Opt: bit_and_expr optimized, nbits = 25
#   Bit Value Opt: eq_expr optimized, nbits = 25
#   Bit Value Opt: bit_and_expr optimized, nbits = 26
#   Bit Value Opt: eq_expr optimized, nbits = 26
#   Bit Value Opt: bit_and_expr optimized, nbits = 26
#   Bit Value Opt: ne_expr optimized, nbits = 26
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: bit_and_expr optimized, nbits = 1
#   Bit Value Opt: ne_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: bit_and_expr optimized, nbits = 22
#   Bit Value Opt: ne_expr optimized, nbits = 22
#   Bit Value Opt: bit_and_expr optimized, nbits = 47
#   Bit Value Opt: ne_expr optimized, nbits = 47
#   Bit Value Opt: bit_and_expr optimized, nbits = 9
#   Bit Value Opt: ne_expr optimized, nbits = 9
#   Bit Value Opt: bit_and_expr optimized, nbits = 24
#   Bit Value Opt: ne_expr optimized, nbits = 24
#
#   Memory allocation information:
# Warning: This function uses unknown addresses: main_kernel
#     BRAM bitsize: 16
#     Spec may not exploit DATA bus width
#     Spec accesses data having an address unknown at compile time
#     Internal data is not externally accessible
#     DATA bus bitsize: 32
#     ADDRESS bus bitsize: 32
#     SIZE bus bitsize: 6
#     Internally allocated memory (no private memories): 0
#     Internally allocated memory: 0
#   Time to perform memory allocation: 0.00 seconds
#
#
#   Module allocation information for function __float_adde8m23b_127rnh:
#     Number of complex operations: 0
#     Number of complex operations: 0
#   Time to perform module allocation: 0.08 seconds
#
#
#   Module allocation information for function __float_mule8m23b_127rnh:
#     Number of complex operations: 0
#     Number of complex operations: 0
#   Time to perform module allocation: 0.06 seconds
#
#
#   Scheduling Information of function __float_adde8m23b_127rnh:
#     Number of control steps: 4
#     Minimum slack: 0.051269958999998477
#     Estimated max frequency (MHz): 202.07204509339684
#   Time to perform scheduling: 0.04 seconds
#
#   Number of function call sites = 128
#
#   State Transition Graph Information of function __float_adde8m23b_127rnh:
#     Number of operations: 282
#     Number of basic blocks: 3
#     Number of states: 3
#     Minimum number of cycles: 3
#     Maximum number of cycles 3
#     Parameters are registered
#     Done port is registered
#   Time to perform creation of STG: 0.05 seconds
#
#
#   Scheduling Information of function __float_mule8m23b_127rnh:
#     Number of control steps: 4
#     Minimum slack: 0.087999980999997118
#     Estimated max frequency (MHz): 203.58306110177548
#   Time to perform scheduling: 0.03 seconds
#
#   Number of function call sites = 128
#
#   State Transition Graph Information of function __float_mule8m23b_127rnh:
#     Number of operations: 223
#     Number of basic blocks: 3
#     Number of states: 3
#     Minimum number of cycles: 3
#     Maximum number of cycles 3
#     Parameters are registered
#     Done port is registered
#   Time to perform creation of STG: 0.03 seconds
#
#
#   Easy binding information for function __float_adde8m23b_127rnh:
#     Bound operations:115/282
#   Time to perform easy binding: 0.00 seconds
#
#
#   Easy binding information for function __float_mule8m23b_127rnh:
#     Bound operations:102/223
#   Time to perform easy binding: 0.00 seconds
#
#
#   Storage Value Information of function __float_adde8m23b_127rnh:
#     Number of storage values inserted: 15
#   Time to compute storage value information: 0.00 seconds
#
#
#   Storage Value Information of function __float_mule8m23b_127rnh:
#     Number of storage values inserted: 8
#   Time to compute storage value information: 0.00 seconds
#
#
#   Register binding information for function __float_adde8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 15 registers
#   Time to perform register binding: 0.00 seconds
#
#
#   Module binding information for function __float_adde8m23b_127rnh:
#     Number of modules instantiated: 282
#     Number of possible conflicts for possible false paths introduced by resource sharing: 259
#     Estimated resources area (no Muxes and address logic): 193068
#     Estimated area of MUX21: 0
#     Total estimated area: 193068
#     Estimated number of DSPs: 0
#     Slack computed in 0.00 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.01 seconds
#     Clique covering computation:
#       Iteration 0 completed in 0.00 seconds
#       Iteration 1 completed in 0.00 seconds
#   Time to perform module binding: 0.01 seconds
#
#
#   Register binding information for function __float_adde8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 15 registers
#   Time to perform register binding: 0.00 seconds
#
#   Total number of flip-flops in function __float_adde8m23b_127rnh: 165
#   All registers are without enable: function pipelining may come for free
#   Resources are not shared in function __float_adde8m23b_127rnh: function pipelining may come for free
#
#   Register binding information for function __float_mule8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 8 registers
#   Time to perform register binding: 0.00 seconds
#
#
#   Module binding information for function __float_mule8m23b_127rnh:
#     Number of modules instantiated: 223
#     Number of possible conflicts for possible false paths introduced by resource sharing: 6
#     Estimated resources area (no Muxes and address logic): 118284
#     Estimated area of MUX21: 0
#     Total estimated area: 118284
#     Estimated number of DSPs: 0
#     Slack computed in 0.00 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.00 seconds
#     Clique covering computation:
#       Iteration 0 completed in 0.00 seconds
#       Iteration 1 completed in 0.00 seconds
#   Time to perform module binding: 0.00 seconds
#
#
#   Register binding information for function __float_mule8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 8 registers
#   Time to perform register binding: 0.00 seconds
#
#   Total number of flip-flops in function __float_mule8m23b_127rnh: 103
#   All registers are without enable: function pipelining may come for free
#   Resources are not shared in function __float_mule8m23b_127rnh: function pipelining may come for free
#
#   Module allocation information for function main_kernel:
#     Number of complex operations: 352
#     Number of complex operations: 352
#   Time to perform module allocation: 0.04 seconds
#
#
#   Scheduling Information of function main_kernel:
#     Number of control steps: 57
#     Minimum slack: 0.051269956999985877
#     Estimated max frequency (MHz): 202.0720450117301
#   Time to perform scheduling: 0.33 seconds
#
#   Number of function call sites = 0
#
#   State Transition Graph Information of function main_kernel:
#     Number of operations: 1011
#     Number of basic blocks: 3
#     Number of states: 55
#     Minimum number of cycles: 55
#     Maximum number of cycles 55
#     Done port is registered
#   Time to perform creation of STG: 0.63 seconds
#
#
#   Easy binding information for function main_kernel:
#     Bound operations:582/1011
#   Time to perform easy binding: 0.00 seconds
#
#
#   Storage Value Information of function main_kernel:
#     Number of storage values inserted: 415
#   Time to compute storage value information: 0.00 seconds
#
#   cdfc mux estimation 93 -- Number of cliques covering the graph: 2 main_kernel_BMEMORY_CTRLN_582 with 96 vertices
#   cdfc mux estimation 224 -- Number of cliques covering the graph: 16 main_kernel___float_adde8m23b_127rnh_614 with 128 vertices
#   cdfc mux estimation 222 -- Number of cliques covering the graph: 16 main_kernel___float_mule8m23b_127rnh_615 with 128 vertices
#
#   Register binding information for function main_kernel:
#     Register allocation algorithm obtains a sub-optimal result: 415 registers(LB:102)
#   Time to perform register binding: 0.12 seconds
#
#   cdfc mux estimation 93 -- Number of cliques covering the graph: 2 main_kernel_BMEMORY_CTRLN_582 with 96 vertices
#   cdfc mux estimation 224 -- Number of cliques covering the graph: 16 main_kernel___float_adde8m23b_127rnh_614 with 128 vertices
#   cdfc mux estimation 222 -- Number of cliques covering the graph: 16 main_kernel___float_mule8m23b_127rnh_615 with 128 vertices
#
#   Module binding information for function main_kernel:
#     Number of modules instantiated: 693
#     Number of possible conflicts for possible false paths introduced by resource sharing: 0
#     Estimated resources area (no Muxes and address logic): 320914
#     Estimated area of MUX21: 1137057.7
#     Total estimated area: 1457971.7
#     Estimated number of DSPs: 0
#     Slack computed in 0.01 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.08 seconds
#     Clique covering computation:
#       Iteration 0 completed in 1.36 seconds
#       Iteration 1 completed in 1.36 seconds
#   Time to perform module binding: 2.96 seconds
#
#
#   Register binding information for function main_kernel:
#     Register allocation algorithm obtains a sub-optimal result: 415 registers(LB:102)
#   Time to perform register binding: 0.13 seconds
#
#
#   Connection Binding Information for function main_kernel:
#     Number of allocated multiplexers (2-to-1 equivalent): 539
#     Total number of bit-level multiplexers: 17248
#   Time to perform interconnection binding: 0.03 seconds
#
#   Total number of flip-flops in function main_kernel: 13280
#  .:: Creating Generic Bash Backend Flow ::.
#   Parameter P0 (494024) (testvector 0) allocated at 1073741824 : reserved_mem_size = 128
#   Parameter P1 (494025) (testvector 0) allocated at 1073741952 : reserved_mem_size = 128
#   Parameter P2 (494026) (testvector 0) allocated at 1073742080 : reserved_mem_size = 64
#   C-based testbench generation for function main_kernel: /working_dir/HLS_output//simulation/values.c
#   Prepared testbench
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
#
#   Summary of resources:
#      - ASSIGN_UNSIGNED_FU: 16
#      - ASSIGN_VECTOR_BOOL_FU: 16
#      - BMEMORY_CTRLN: 1
#      - IIdata_converter_FU: 32
#      - IUdata_converter_FU: 128
#      - MUX_GATE: 539
#      - OR_GATE: 32
#      - UIdata_converter_FU: 128
#      - UUdata_converter_FU: 2084
#      - bus_merger: 5
#      - constant_value: 817
#      - flipflop_AR: 32
#      - join_signal: 5
#      - lshift_expr_FU: 32
#      - register_SE: 411
#      - register_STD: 436
#      - rshift_expr_FU: 128
#      - split_signal: 5
#      - truth_and_expr_FU: 960
#      - truth_not_expr_FU: 16
#      - truth_or_expr_FU: 176
#      - truth_xor_expr_FU: 64
#      - ui_bit_and_expr_FU: 1248
#      - ui_bit_ior_concat_expr_FU: 16
#      - ui_bit_ior_expr_FU: 640
#      - ui_bit_xor_expr_FU: 256
#      - ui_cond_expr_FU: 576
#      - ui_eq_expr_FU: 416
#      - ui_extract_bit_expr_FU: 128
#      - ui_lshift_expr_FU: 752
#      - ui_lt_expr_FU: 32
#      - ui_minus_expr_FU: 16
#      - ui_mult_expr_FU: 16
#      - ui_ne_expr_FU: 272
#      - ui_plus_expr_FU: 80
#      - ui_pointer_plus_expr_FU: 77
#      - ui_rshift_expr_FU: 768
#      - ui_ternary_plus_expr_FU: 16
#      - ui_ternary_pm_expr_FU: 16
# make: Entering directory '/working_dir/HLS_output/verilator_beh/verilator_obj'
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o testbench_main_kernel_main.o /working_dir/HLS_output//simulation/testbench_main_kernel_main.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o verilated.o /usr/share/verilator/include/verilated.cpp
# /usr/bin/perl /usr/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include Vmain_kernel_tb.cpp > Vmain_kernel_tb__ALLcls.cpp
# /usr/bin/perl /usr/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include Vmain_kernel_tb__Syms.cpp > Vmain_kernel_tb__ALLsup.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o Vmain_kernel_tb__ALLcls.o Vmain_kernel_tb__ALLcls.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o Vmain_kernel_tb__ALLsup.o Vmain_kernel_tb__ALLsup.cpp
# ar -cr Vmain_kernel_tb__ALL.a Vmain_kernel_tb__ALLcls.o Vmain_kernel_tb__ALLsup.o
# ranlib Vmain_kernel_tb__ALL.a
# g++    testbench_main_kernel_main.o verilated.o Vmain_kernel_tb__ALL.a    -o Vmain_kernel_tb -lm -lstdc++
# make: Leaving directory '/working_dir/HLS_output/verilator_beh/verilator_obj'
# Start reading vector           1's values from input file.
#
# Reading of vector values from input file completed. Simulation started.
# Simulation ended after                   55 cycles.
#
# Simulation completed with success
#
# - /working_dir/HLS_output//simulation/testbench_main_kernel_tb.v:681: Verilog $finish
# Start reading vector           1's values from input file.
#
# Reading of vector values from input file completed. Simulation started.
# Simulation ended after                   55 cycles.
#
# Simulation completed with success
#
# - /working_dir/HLS_output//simulation/testbench_main_kernel_tb.v:681: Verilog $finish
# File "/working_dir/results.txt" opened
# 1. Simulation completed with SUCCESS; Execution time 55 cycles;
#   Total cycles             : 55 cycles
#   Number of executions     : 1
#   Average execution        : 55 cycles
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version

# %%
optimized_runtime = ""

for runtime in open('output/optimized/bambu-log').readlines():
    if "Average execution" in runtime:
        optimized_runtime = [int(s) for s in runtime.split() if s.isdigit()][0]

print("Average execution in cycles: {}".format(optimized_runtime))
# Out:
# Average execution in cycles: 55

# %% [markdown]
# Visualize [Intermediate Dot File](output/optimized/HLS_output/dot/main_kernel/HLS_STGraph.dot)

# %% [markdown]
# ## Comparison of runtime results
#
# * Display runtime
# * Display [verilog output file](output/optimized/main_kernel.v)

# %%
print("Average execution in cycles of Baseline kernel:  {}".format(baseline_runtime))
print("Average execution in cycles of Optimized kernel: {}".format(optimized_runtime))
print("Speedup: {:.1f}".format(float(baseline_runtime/optimized_runtime)))
# Out:
# Average execution in cycles of Baseline kernel:  1158
# Average execution in cycles of Optimized kernel: 55
# Speedup: 21.1

# %% [markdown]
# # Commandline interface
#
# To visualize all possible paramenters for our optimization passes run:
#
# - `soda-opt -h`

# %% [markdown]
# ```
#       --soda-opt-pipeline-for-bambu
#         --affine-tile-size=<ulong>
#         --bitwidth-of-index-type=<uint>
#         --max-alloc-size-in-bytes=<uint>
#         --max-rank-of-allocated-memref=<uint>
#         --number-of-full-unrolls=<uint>
#         --permutation-map=<uint>
#         --use-bare-ptr-memref-call-conv
#         --no-alloca-promotion
#         --no-buffer-trick
#         --no-scalar-replacement
#
# ```

# %%
# %%bash
# (
#   docker run -u $(id -u) -v $(pwd):/working_dir --rm agostini01/soda \
#   soda-opt -h 2>&1 | cat > output/helpfile
# )

# %% [markdown]
# Open [help file](output/helpfile)

# %% [markdown]
# ### Modifying the number of unrolls

# %%
# %%bash
# (
#   docker run -u $(id -u) -v $(pwd):/working_dir --rm agostini01/soda \
#   soda-opt \
#     -soda-outline-bambu-code \
#     -soda-extract-arguments-to-xml=using-bare-ptr \
#     -soda-generate-bambu-accelcode \
#     -soda-opt-pipeline-for-bambu="use-bare-ptr-memref-call-conv number-of-full-unrolls=1" \
#     -print-ir-after-all \
#     output/01searched-edited.mlir \
#     -o output/04optimized.mlir \
#     2>&1 | cat > output/05intermediate-optimized.mlir
#
#   docker run -u $(id -u) -v $(pwd):/working_dir --rm agostini01/soda \
#   mlir-translate \
#     --mlir-to-llvmir \
#     output/04optimized.mlir \
#     -o output/05optimized.ll
# )

# %% [markdown]
# Visualize [intermediate file](output/05intermediate-optimized.mlir)

# %%
! scripts/run-bambu.sh optimized
# Out:
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version/output/optimized /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version
#  ==  Bambu executed with: bambu -v3 --print-dot -lm --soft-float --compiler=I386_CLANG10 -O2 --device=nangate45 --clock-period=5 --no-iob --experimental-setup=BAMBU-BALANCED-MP --channels-number=2 --memory-allocation-policy=ALL_BRAM --disable-function-proxy --generate-tb=main_kernel_test.xml --simulate --simulator=VERILATOR --top-fname=main_kernel input.ll
#
#
# ********************************************************************************
#                     ____                  _
#                    | __ )  __ _ _ __ ___ | |_   _   _
#                    |  _ \ / _` | '_ ` _ \| '_ \| | | |
#                    | |_) | (_| | | | | | | |_) | |_| |
#                    |____/ \__,_|_| |_| |_|_.__/ \__,_|
#
# ********************************************************************************
#                          High-Level Synthesis Tool
#
#                          Politecnico di Milano - DEIB
#                           System Architectures Group
# ********************************************************************************
#                 Copyright (C) 2004-2021 Politecnico di Milano
#   Version: PandA 0.9.7-dev - Revision 891ec3caed502474cab0813cc4a9fc678deabaa5
#
# Parameters parsed in 0.14 seconds
#
# Target technology = FPGA
# Library Name     : STD_FU
#   Total cells    : 3
#   - combinational: 0
#   - others: 3
#
# Library Name     : STD_FU
#   Total cells    : 10
#   - combinational: 0
#   - others: 10
#
# Library Name     : STD_FU
#   Total cells    : 31
#   - combinational: 0
#   - others: 31
#
# Library Name     : STD_FU
#   Total cells    : 8
#   - combinational: 0
#   - others: 8
#
# Library Name     : STD_FU
#   Total cells    : 56
#   - combinational: 0
#   - others: 56
#
# Library Name     : STD_FU
#   Total cells    : 1
#   - combinational: 0
#   - others: 1
#
# Library Name     : CS_COMPONENT
#   Total cells    : 16
#   - combinational: 0
#   - others: 16
#
# Library Name     : STD_FU
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD_FU
#   Total cells    : 0
#   - combinational: 0
#   - others: 0
#
# Library Name     : STD_FU
#   Total cells    : 0
#   - combinational: 0
#   - others: 0
#
# Library Name     : STD_FU
#   Total cells    : 17
#   - combinational: 0
#   - others: 17
#
# Library Name     : STD
#   Total cells    : 14
#   - combinational: 0
#   - others: 14
#
# Library Name     : STD_COMMON
#   Total cells    : 57
#   - combinational: 0
#   - others: 57
#
# Library Name     : STD_FU
#   Total cells    : 8
#   - combinational: 0
#   - others: 8
#
# Library Name     : STD_PC
#   Total cells    : 16
#   - combinational: 0
#   - others: 16
#
# Library Name     : STD_SOFT_FLOAT
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD
#   Total cells    : 72
#   - combinational: 0
#   - others: 72
#
# Library Name     : STD_FU
#   Total cells    : 2
#   - combinational: 0
#   - others: 2
#
# Library Name     : STD_FU
#   Total cells    : 4
#   - combinational: 0
#   - others: 4
#
# Library Name     : WBWrapper
#   Total cells    : 12
#   - combinational: 0
#   - others: 12
#
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
#  (in-process)  /usr/local/include  /usr/lib/llvm-10/lib/clang/10.0.0/include  /usr/include/x86_64-linux-gnu  /usr/include  warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
#
# Available devices:
#  - 5CSEMA5F31C6
#  - 5SGXEA7N2F45C1
#  - EP2C70F896C6
#  - EP2C70F896C6-R
#  - EP4SGX530KH40C2
#  - LFE335EA8FN484C
#  - LFE5U85F8BG756C
#  - LFE5UM85F8BG756C
#  - nangate45
#  - nx1h140tsp
#  - nx1h35S
#  - xc4vlx100-10ff1513
#  - xc5vlx110t-1ff1136
#  - xc5vlx330t-2ff1738
#  - xc5vlx50-3ff1153
#  - xc6vlx240t-1ff1156
#  - xc7a100t-1csg324-VVD
#  - xc7vx330t-1ffg1157
#  - xc7vx485t-2ffg1761-VVD
#  - xc7vx690t-3ffg1930-VVD
#  - xc7z020-1clg484
#  - xc7z020-1clg484-VVD
#  - xc7z020-1clg484-YOSYS-VVD
#  - xc7z045-2ffg900-VVD
# Library Name     : STD_FU
#   Total cells    : 4303
#   - combinational: 0
#   - others: 4303
#
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: minus_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 3
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 2
#   Bit Value Opt: cond_expr optimized, nbits = 3
#   Bit Value Opt: cond_expr optimized, nbits = 4
#   Bit Value Opt: cond_expr optimized, nbits = 5
#   Bit Value Opt: bit_xor_expr optimized, nbits = 2
#   Bit Value Opt: bit_and_expr optimized, nbits = 2
#   Bit Value Opt: ne_expr optimized, nbits = 2
#   Bit Value Opt: plus_expr optimized, nbits = 2
#   Bit Value Opt: bit_and_expr optimized, nbits = 11
#   Bit Value Opt: eq_expr optimized, nbits = 11
#   Bit Value Opt: bit_and_expr optimized, nbits = 19
#   Bit Value Opt: eq_expr optimized, nbits = 19
#   Bit Value Opt: bit_and_expr optimized, nbits = 23
#   Bit Value Opt: eq_expr optimized, nbits = 23
#   Bit Value Opt: bit_and_expr optimized, nbits = 25
#   Bit Value Opt: eq_expr optimized, nbits = 25
#   Bit Value Opt: bit_and_expr optimized, nbits = 26
#   Bit Value Opt: eq_expr optimized, nbits = 26
#   Bit Value Opt: bit_and_expr optimized, nbits = 26
#   Bit Value Opt: ne_expr optimized, nbits = 26
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: bit_and_expr optimized, nbits = 1
#   Bit Value Opt: ne_expr optimized, nbits = 1
#   Bit Value Opt: cond_expr optimized, nbits = 1
#   Bit Value Opt: bit_and_expr optimized, nbits = 22
#   Bit Value Opt: ne_expr optimized, nbits = 22
#   Bit Value Opt: bit_and_expr optimized, nbits = 47
#   Bit Value Opt: ne_expr optimized, nbits = 47
#   Bit Value Opt: bit_and_expr optimized, nbits = 9
#   Bit Value Opt: ne_expr optimized, nbits = 9
#   Bit Value Opt: bit_and_expr optimized, nbits = 24
#   Bit Value Opt: ne_expr optimized, nbits = 24
#
#   Memory allocation information:
#     Internal variable: internal_494484 - 494484 - internal_494484 in function main_kernel
#       Id: 494484
#       Base Address: 512
#       Size: 512
#       Is a private memory
#       The variable is always accessed with the same data size
#       Number of functions in which is used: 1
#       Maximum number of references per function: 40
#       Maximum number of loads per function: 8
#     Internal variable: internal_494966 - 494966 - internal_494966 in function main_kernel
#       Id: 494966
#       Base Address: 512
#       Size: 512
#       Is a private memory
#       The variable is always accessed with the same data size
#       Number of functions in which is used: 1
#       Maximum number of references per function: 64
#       Maximum number of loads per function: 32
#     Internal variable: internal_495414 - 495414 - internal_495414 in function main_kernel
#       Id: 495414
#       Base Address: 512
#       Size: 256
#       Is a private memory
#       The variable is always accessed with the same data size
#       Number of functions in which is used: 1
#       Maximum number of references per function: 40
#       Maximum number of loads per function: 20
# Warning: This function uses unknown addresses: main_kernel
#     BRAM bitsize: 16
#     Spec may not exploit DATA bus width
#     Spec accesses data having an address unknown at compile time
#     Internal data is not externally accessible
#     DATA bus bitsize: 32
#     ADDRESS bus bitsize: 32
#     SIZE bus bitsize: 6
#     Internally allocated memory (no private memories): 0
#     Internally allocated memory: 1280
#   Time to perform memory allocation: 0.00 seconds
#
#
#   Module allocation information for function __float_adde8m23b_127rnh:
#     Number of complex operations: 0
#     Number of complex operations: 0
#   Time to perform module allocation: 0.07 seconds
#
#
#   Module allocation information for function __float_mule8m23b_127rnh:
#     Number of complex operations: 0
#     Number of complex operations: 0
#   Time to perform module allocation: 0.06 seconds
#
#
#   Scheduling Information of function __float_adde8m23b_127rnh:
#     Number of control steps: 4
#     Minimum slack: 0.051269958999998477
#     Estimated max frequency (MHz): 202.07204509339684
#   Time to perform scheduling: 0.04 seconds
#
#   Number of function call sites = 32
#
#   State Transition Graph Information of function __float_adde8m23b_127rnh:
#     Number of operations: 282
#     Number of basic blocks: 3
#     Number of states: 3
#     Minimum number of cycles: 3
#     Maximum number of cycles 3
#     Parameters are registered
#     Done port is registered
#   Time to perform creation of STG: 0.05 seconds
#
#
#   Scheduling Information of function __float_mule8m23b_127rnh:
#     Number of control steps: 4
#     Minimum slack: 0.087999980999997118
#     Estimated max frequency (MHz): 203.58306110177548
#   Time to perform scheduling: 0.03 seconds
#
#   Number of function call sites = 32
#
#   State Transition Graph Information of function __float_mule8m23b_127rnh:
#     Number of operations: 223
#     Number of basic blocks: 3
#     Number of states: 3
#     Minimum number of cycles: 3
#     Maximum number of cycles 3
#     Parameters are registered
#     Done port is registered
#   Time to perform creation of STG: 0.02 seconds
#
#
#   Easy binding information for function __float_adde8m23b_127rnh:
#     Bound operations:115/282
#   Time to perform easy binding: 0.00 seconds
#
#
#   Easy binding information for function __float_mule8m23b_127rnh:
#     Bound operations:102/223
#   Time to perform easy binding: 0.00 seconds
#
#
#   Storage Value Information of function __float_adde8m23b_127rnh:
#     Number of storage values inserted: 15
#   Time to compute storage value information: 0.00 seconds
#
#
#   Storage Value Information of function __float_mule8m23b_127rnh:
#     Number of storage values inserted: 8
#   Time to compute storage value information: 0.00 seconds
#
#
#   Register binding information for function __float_adde8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 15 registers
#   Time to perform register binding: 0.00 seconds
#
#
#   Module binding information for function __float_adde8m23b_127rnh:
#     Number of modules instantiated: 282
#     Number of possible conflicts for possible false paths introduced by resource sharing: 259
#     Estimated resources area (no Muxes and address logic): 193068
#     Estimated area of MUX21: 0
#     Total estimated area: 193068
#     Estimated number of DSPs: 0
#     Slack computed in 0.00 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.00 seconds
#     Clique covering computation:
#       Iteration 0 completed in 0.00 seconds
#       Iteration 1 completed in 0.00 seconds
#   Time to perform module binding: 0.01 seconds
#
#
#   Register binding information for function __float_adde8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 15 registers
#   Time to perform register binding: 0.00 seconds
#
#   Total number of flip-flops in function __float_adde8m23b_127rnh: 165
#   All registers are without enable: function pipelining may come for free
#   Resources are not shared in function __float_adde8m23b_127rnh: function pipelining may come for free
#
#   Register binding information for function __float_mule8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 8 registers
#   Time to perform register binding: 0.00 seconds
#
#
#   Module binding information for function __float_mule8m23b_127rnh:
#     Number of modules instantiated: 223
#     Number of possible conflicts for possible false paths introduced by resource sharing: 6
#     Estimated resources area (no Muxes and address logic): 118284
#     Estimated area of MUX21: 0
#     Total estimated area: 118284
#     Estimated number of DSPs: 0
#     Slack computed in 0.00 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.00 seconds
#     Clique covering computation:
#       Iteration 0 completed in 0.00 seconds
#       Iteration 1 completed in 0.00 seconds
#   Time to perform module binding: 0.00 seconds
#
#
#   Register binding information for function __float_mule8m23b_127rnh:
#     Register allocation algorithm obtains an optimal result: 8 registers
#   Time to perform register binding: 0.00 seconds
#
#   Total number of flip-flops in function __float_mule8m23b_127rnh: 103
#   All registers are without enable: function pipelining may come for free
#   Resources are not shared in function __float_mule8m23b_127rnh: function pipelining may come for free
#
#   Module allocation information for function main_kernel:
#     Number of complex operations: 304
#     Number of complex operations: 304
#   Time to perform module allocation: 0.05 seconds
#
#
#   Scheduling Information of function main_kernel:
#     Number of control steps: 95
#     Minimum slack: 0.051269957000042721
#     Estimated max frequency (MHz): 202.07204501173243
#   Time to perform scheduling: 0.15 seconds
#
#   Number of function call sites = 0
#
#   State Transition Graph Information of function main_kernel:
#     Number of operations: 843
#     Number of basic blocks: 5
#     Number of states: 93
#     Done port is registered
#   Time to perform creation of STG: 0.26 seconds
#
#
#   Easy binding information for function main_kernel:
#     Bound operations:353/843
#   Time to perform easy binding: 0.01 seconds
#
#
#   Storage Value Information of function main_kernel:
#     Number of storage values inserted: 409
#   Time to compute storage value information: 0.00 seconds
#
#   cdfc mux estimation 68 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_0 with 40 vertices
#   cdfc mux estimation 92 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_1 with 64 vertices
#   cdfc mux estimation 38 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_2 with 40 vertices
#   cdfc mux estimation 78 -- Number of cliques covering the graph: 2 main_kernel_BMEMORY_CTRLN_348 with 96 vertices
#   cdfc mux estimation 56 -- Number of cliques covering the graph: 4 main_kernel___float_adde8m23b_127rnh_394 with 32 vertices
#   cdfc mux estimation 16 -- Number of cliques covering the graph: 8 main_kernel___float_mule8m23b_127rnh_395 with 16 vertices
#
#   Register binding information for function main_kernel:
#     Register allocation algorithm obtains a sub-optimal result: 326 registers(LB:192)
#   Time to perform register binding: 0.17 seconds
#
#   cdfc mux estimation 38 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_0 with 40 vertices
#   cdfc mux estimation 73 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_1 with 64 vertices
#   cdfc mux estimation 24 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_2 with 40 vertices
#   cdfc mux estimation 78 -- Number of cliques covering the graph: 2 main_kernel_BMEMORY_CTRLN_348 with 96 vertices
#   cdfc mux estimation 56 -- Number of cliques covering the graph: 4 main_kernel___float_adde8m23b_127rnh_394 with 32 vertices
#   cdfc mux estimation 16 -- Number of cliques covering the graph: 8 main_kernel___float_mule8m23b_127rnh_395 with 16 vertices
#
#   Register binding information for function main_kernel:
#     Register allocation algorithm obtains a sub-optimal result: 326 registers(LB:192)
#   Time to perform register binding: 0.16 seconds
#
#   cdfc mux estimation 38 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_0 with 40 vertices
#   cdfc mux estimation 73 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_1 with 64 vertices
#   cdfc mux estimation 24 -- Number of cliques covering the graph: 2 main_kernel_ARRAY_1D_STD_BRAM_NN_SDS_2 with 40 vertices
#   cdfc mux estimation 78 -- Number of cliques covering the graph: 2 main_kernel_BMEMORY_CTRLN_348 with 96 vertices
#   cdfc mux estimation 56 -- Number of cliques covering the graph: 4 main_kernel___float_adde8m23b_127rnh_394 with 32 vertices
#   cdfc mux estimation 16 -- Number of cliques covering the graph: 8 main_kernel___float_mule8m23b_127rnh_395 with 16 vertices
#
#   Module binding information for function main_kernel:
#     Number of modules instantiated: 575
#     Number of possible conflicts for possible false paths introduced by resource sharing: 0
#     Estimated resources area (no Muxes and address logic): 3647810
#     Estimated area of MUX21: 594824
#     Total estimated area: 4242634
#     Estimated number of DSPs: 0
#     Slack computed in 0.01 seconds
#     False-loop computation completed in 0.00 seconds
#     Weight computation completed in 0.04 seconds
#     Clique covering computation:
#       Iteration 0 completed in 0.06 seconds
#       Iteration 1 completed in 0.06 seconds
#       Iteration 2 completed in 0.06 seconds
#   Time to perform module binding: 0.56 seconds
#
#
#   Register binding information for function main_kernel:
#     Register allocation algorithm obtains a sub-optimal result: 326 registers(LB:192)
#   Time to perform register binding: 0.16 seconds
#
#
#   Connection Binding Information for function main_kernel:
#     Number of allocated multiplexers (2-to-1 equivalent): 363
#     Total number of bit-level multiplexers: 9008
#   Time to perform interconnection binding: 0.02 seconds
#
#   Total number of flip-flops in function main_kernel: 10433
#  .:: Creating Generic Bash Backend Flow ::.
#   Parameter P0 (494024) (testvector 0) allocated at 1073741824 : reserved_mem_size = 128
#   Parameter P1 (494025) (testvector 0) allocated at 1073742336 : reserved_mem_size = 128
#   Parameter P2 (494026) (testvector 0) allocated at 1073742848 : reserved_mem_size = 64
#   C-based testbench generation for function main_kernel: /working_dir/HLS_output//simulation/values.c
#   Prepared testbench
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
#
#   Summary of resources:
#      - ARRAY_1D_STD_BRAM_NN_SDS: 3
#      - ASSIGN_UNSIGNED_FU: 5
#      - ASSIGN_VECTOR_BOOL_FU: 100
#      - BMEMORY_CTRLN: 1
#      - IIdata_converter_FU: 8
#      - IUdata_converter_FU: 132
#      - MUX_GATE: 363
#      - OR_GATE: 12
#      - UIdata_converter_FU: 132
#      - UUdata_converter_FU: 1358
#      - addr_expr_FU: 3
#      - bus_merger: 5
#      - constant_value: 678
#      - flipflop_AR: 28
#      - join_signal: 5
#      - lshift_expr_FU: 8
#      - read_cond_FU: 1
#      - register_SE: 318
#      - register_STD: 316
#      - rshift_expr_FU: 132
#      - split_signal: 5
#      - truth_and_expr_FU: 562
#      - truth_not_expr_FU: 4
#      - truth_or_expr_FU: 104
#      - truth_xor_expr_FU: 36
#      - ui_bit_and_expr_FU: 1092
#      - ui_bit_ior_concat_expr_FU: 4
#      - ui_bit_ior_expr_FU: 610
#      - ui_bit_xor_expr_FU: 224
#      - ui_cond_expr_FU: 344
#      - ui_eq_expr_FU: 404
#      - ui_extract_bit_expr_FU: 112
#      - ui_lshift_expr_FU: 582
#      - ui_lt_expr_FU: 9
#      - ui_minus_expr_FU: 4
#      - ui_mult_expr_FU: 24
#      - ui_ne_expr_FU: 268
#      - ui_plus_expr_FU: 61
#      - ui_pointer_plus_expr_FU: 166
#      - ui_rshift_expr_FU: 572
#      - ui_ternary_plus_expr_FU: 24
#      - ui_ternary_pm_expr_FU: 4
#      - ui_view_convert_expr_FU: 160
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# clang: warning: optimization flag '-ffloat-store' is not supported [-Wignored-optimization-argument]
# warning: overriding the module target triple with i386-pc-linux-gnu [-Woverride-module]
# 1 warning generated.
# make: Entering directory '/working_dir/HLS_output/verilator_beh/verilator_obj'
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o testbench_main_kernel_main.o /working_dir/HLS_output//simulation/testbench_main_kernel_main.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o verilated.o /usr/share/verilator/include/verilated.cpp
# /usr/bin/perl /usr/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include Vmain_kernel_tb.cpp > Vmain_kernel_tb__ALLcls.cpp
# /usr/bin/perl /usr/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include Vmain_kernel_tb__Syms.cpp > Vmain_kernel_tb__ALLsup.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o Vmain_kernel_tb__ALLcls.o Vmain_kernel_tb__ALLcls.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=0 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow  -fstrict-aliasing     -c -o Vmain_kernel_tb__ALLsup.o Vmain_kernel_tb__ALLsup.cpp
# ar -cr Vmain_kernel_tb__ALL.a Vmain_kernel_tb__ALLcls.o Vmain_kernel_tb__ALLsup.o
# ranlib Vmain_kernel_tb__ALL.a
# g++    testbench_main_kernel_main.o verilated.o Vmain_kernel_tb__ALL.a    -o Vmain_kernel_tb -lm -lstdc++
# make: Leaving directory '/working_dir/HLS_output/verilator_beh/verilator_obj'
# Start reading vector           1's values from input file.
#
# Reading of vector values from input file completed. Simulation started.
# Simulation ended after                  186 cycles.
#
# Simulation completed with success
#
# - /working_dir/HLS_output//simulation/testbench_main_kernel_tb.v:681: Verilog $finish
# Start reading vector           1's values from input file.
#
# Reading of vector values from input file completed. Simulation started.
# Simulation ended after                  186 cycles.
#
# Simulation completed with success
#
# - /working_dir/HLS_output//simulation/testbench_main_kernel_tb.v:681: Verilog $finish
# File "/working_dir/results.txt" opened
# 1. Simulation completed with SUCCESS; Execution time 186 cycles;
#   Total cycles             : 186 cycles
#   Number of executions     : 1
#   Average execution        : 186 cycles
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version

# %% [markdown]
# ![tutorial-flow](imgs/flow-diagram.png)

# %% [markdown]
# # OpenRoad Flow: Automatic ASIC place and route (Step 6)

# %% [markdown]
# ### Baseline kernel

# %%
! scripts/run-openroad.sh baseline

# Approx. 4min to execute
# Out:
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version/output/baseline /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version
# [INFO][FLOW] Using platform directory /OpenROAD-flow-scripts/flow/platforms/nangate45
# /OpenROAD-flow-scripts/flow/util/markDontUse.py -p "TAPCELL_X1 FILLCELL_X1 AOI211_X1 OAI211_X1" -i /OpenROAD-flow-scripts/flow/platforms/nangate45/lib/NangateOpenCellLibrary_typical.lib -o /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/lib/NangateOpenCellLibrary_typical.lib
# Opening file for replace: /OpenROAD-flow-scripts/flow/platforms/nangate45/lib/NangateOpenCellLibrary_typical.lib
# Marked 4 cells as dont_use
# Commented 0 lines containing "original_pin"
# Writing replaced file: /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/lib/NangateOpenCellLibrary_typical.lib
# mkdir -p /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/reports/nangate45/main_kernel/base
# (/usr/bin/time -f 'Elapsed time: %E[h:]min:sec. CPU time: user %U sys %S (%P). Peak memory: %MKB.' /OpenROAD-flow-scripts/tools/install/yosys/bin/yosys -v 3 -c /OpenROAD-flow-scripts/flow/scripts/synth.tcl) 2>&1 | tee /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base/1_1_yosys.log
# 1. Executing Verilog-2005 frontend: ./main_kernel.v
# 2. Executing Liberty frontend.
# 3. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/flow/platforms/nangate45/cells_clkgate.v
# 4. Executing SYNTH pass.
# 4.1. Executing HIERARCHY pass (managing design hierarchy).
# 4.2. Executing AST frontend in derive mode using pre-parsed AST for module `\main_kernel'.
# 4.2.1. Analyzing design hierarchy..
# 4.2.2. Executing AST frontend in derive mode using pre-parsed AST for module `\_main_kernel'.
# 4.2.3. Analyzing design hierarchy..
# 4.2.4. Executing AST frontend in derive mode using pre-parsed AST for module `\flipflop_AR'.
# 4.2.5. Executing AST frontend in derive mode using pre-parsed AST for module `\datapath_main_kernel'.
# 4.2.6. Executing AST frontend in derive mode using pre-parsed AST for module `\controller_main_kernel'.
# 4.2.7. Analyzing design hierarchy..
# 4.2.8. Executing AST frontend in derive mode using pre-parsed AST for module `\split_signal'.
# 4.2.9. Executing AST frontend in derive mode using pre-parsed AST for module `\split_signal'.
# 4.2.10. Executing AST frontend in derive mode using pre-parsed AST for module `\split_signal'.
# 4.2.11. Executing AST frontend in derive mode using pre-parsed AST for module `\register_SE'.
# 4.2.12. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.13. Executing AST frontend in derive mode using pre-parsed AST for module `\register_SE'.
# 4.2.14. Executing AST frontend in derive mode using pre-parsed AST for module `\register_SE'.
# 4.2.15. Executing AST frontend in derive mode using pre-parsed AST for module `\register_SE'.
# 4.2.16. Executing AST frontend in derive mode using pre-parsed AST for module `\join_signal'.
# 4.2.17. Executing AST frontend in derive mode using pre-parsed AST for module `\join_signal'.
# 4.2.18. Executing AST frontend in derive mode using pre-parsed AST for module `\join_signal'.
# 4.2.19. Executing AST frontend in derive mode using pre-parsed AST for module `\truth_and_expr_FU'.
# 4.2.20. Executing AST frontend in derive mode using pre-parsed AST for module `\truth_not_expr_FU'.
# 4.2.21. Executing AST frontend in derive mode using pre-parsed AST for module `\multi_read_cond_FU'.
# 4.2.22. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.23. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.24. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.25. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.26. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.27. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.28. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.29. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.30. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.31. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.32. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.33. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.34. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.35. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.36. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.37. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.38. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.39. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.40. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.41. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.42. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.43. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lt_expr_FU'.
# 4.2.44. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.45. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.46. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.47. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.48. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.49. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.50. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.51. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.52. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.53. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_concat_expr_FU'.
# 4.2.54. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_concat_expr_FU'.
# 4.2.55. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_concat_expr_FU'.
# 4.2.56. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.57. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.58. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.59. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.60. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.61. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.62. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.63. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.64. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.65. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.66. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.67. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.68. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.69. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.70. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.71. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.72. Executing AST frontend in derive mode using pre-parsed AST for module `\bus_merger'.
# 4.2.73. Executing AST frontend in derive mode using pre-parsed AST for module `\bus_merger'.
# 4.2.74. Executing AST frontend in derive mode using pre-parsed AST for module `\bus_merger'.
# 4.2.75. Executing AST frontend in derive mode using pre-parsed AST for module `\__float_mule8m23b_127rnh'.
# 4.2.76. Executing AST frontend in derive mode using pre-parsed AST for module `\__float_adde8m23b_127rnh'.
# 4.2.77. Executing AST frontend in derive mode using pre-parsed AST for module `\MUX_GATE'.
# 4.2.78. Executing AST frontend in derive mode using pre-parsed AST for module `\MUX_GATE'.
# 4.2.79. Executing AST frontend in derive mode using pre-parsed AST for module `\BMEMORY_CTRLN'.
# 4.2.80. Executing AST frontend in derive mode using pre-parsed AST for module `\ASSIGN_VECTOR_BOOL_FU'.
# 4.2.81. Executing AST frontend in derive mode using pre-parsed AST for module `\ASSIGN_UNSIGNED_FU'.
# 4.2.82. Analyzing design hierarchy..
# 4.2.83. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.84. Executing AST frontend in derive mode using pre-parsed AST for module `\datapath___float_adde8m23b_127rnh'.
# 4.2.85. Executing AST frontend in derive mode using pre-parsed AST for module `\controller___float_adde8m23b_127rnh'.
# 4.2.86. Executing AST frontend in derive mode using pre-parsed AST for module `\datapath___float_mule8m23b_127rnh'.
# 4.2.87. Executing AST frontend in derive mode using pre-parsed AST for module `\controller___float_mule8m23b_127rnh'.
# 4.2.88. Analyzing design hierarchy..
# 4.2.89. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.90. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.91. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.92. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.93. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.94. Executing AST frontend in derive mode using pre-parsed AST for module `\truth_or_expr_FU'.
# 4.2.95. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.96. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.97. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.98. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.99. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.100. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.101. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.102. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_extract_bit_expr_FU'.
# 4.2.103. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.104. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.105. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.106. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.107. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.108. Executing AST frontend in derive mode using pre-parsed AST for module `\truth_xor_expr_FU'.
# 4.2.109. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.110. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ne_expr_FU'.
# 4.2.111. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.112. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ne_expr_FU'.
# 4.2.113. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.114. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.115. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.116. Executing AST frontend in derive mode using pre-parsed AST for module `\UIdata_converter_FU'.
# 4.2.117. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.118. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.119. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.120. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.121. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.122. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.123. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.124. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.125. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.126. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.127. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.128. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.129. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.130. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.131. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.132. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.133. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_xor_expr_FU'.
# 4.2.134. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.135. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.136. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_xor_expr_FU'.
# 4.2.137. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.138. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.139. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.140. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.141. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.142. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.143. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.144. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.145. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.146. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.147. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.148. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.149. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.150. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_mult_expr_FU'.
# 4.2.151. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.152. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.153. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.154. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.155. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.156. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.157. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.158. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.159. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ternary_plus_expr_FU'.
# 4.2.160. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.161. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.162. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.163. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.164. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.165. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.166. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.167. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.168. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.169. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.170. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.171. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.172. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.173. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.174. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.175. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.176. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.177. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.178. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.179. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.180. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.181. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.182. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.183. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.184. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.185. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.186. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.187. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.188. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.189. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.190. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.191. Executing AST frontend in derive mode using pre-parsed AST for module `\ASSIGN_UNSIGNED_FU'.
# 4.2.192. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.193. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.194. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.195. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.196. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.197. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.198. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.199. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.200. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.201. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.202. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.203. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.204. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.205. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.206. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.207. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.208. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.209. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.210. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.211. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.212. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.213. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.214. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.215. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.216. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lt_expr_FU'.
# 4.2.217. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.218. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.219. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.220. Executing AST frontend in derive mode using pre-parsed AST for module `\UIdata_converter_FU'.
# 4.2.221. Executing AST frontend in derive mode using pre-parsed AST for module `\lshift_expr_FU'.
# 4.2.222. Executing AST frontend in derive mode using pre-parsed AST for module `\lshift_expr_FU'.
# 4.2.223. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.224. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.225. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ne_expr_FU'.
# 4.2.226. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.227. Executing AST frontend in derive mode using pre-parsed AST for module `\UIdata_converter_FU'.
# 4.2.228. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.229. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.230. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ne_expr_FU'.
# 4.2.231. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lt_expr_FU'.
# 4.2.232. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.233. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.234. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.235. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.236. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.237. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.238. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.239. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.240. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.241. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.242. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.243. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.244. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.245. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.246. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.247. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.248. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ternary_pm_expr_FU'.
# 4.2.249. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.250. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.251. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.252. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.253. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.254. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.255. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.256. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.257. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.258. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.259. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.260. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.261. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.262. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.263. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.264. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.265. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.266. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.267. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_concat_expr_FU'.
# 4.2.268. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_xor_expr_FU'.
# 4.2.269. Executing AST frontend in derive mode using pre-parsed AST for module `\IIdata_converter_FU'.
# 4.2.270. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.271. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.272. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.273. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_xor_expr_FU'.
# 4.2.274. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.275. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.276. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.277. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.278. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.279. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.280. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.281. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.282. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_minus_expr_FU'.
# 4.2.283. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.284. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.285. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.286. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.287. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.288. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.289. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.290. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.291. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.292. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.293. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.294. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.295. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.296. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.297. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.298. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.299. Analyzing design hierarchy..
# 4.2.300. Analyzing design hierarchy..
# 4.3. Executing PROC pass (convert processes to netlists).
# 4.3.1. Executing PROC_CLEAN pass (remove empty switches from decision trees).
# 4.3.2. Executing PROC_RMDEAD pass (remove dead branches from decision trees).
# 4.3.3. Executing PROC_PRUNE pass (remove redundant assignments in processes).
# 4.3.4. Executing PROC_INIT pass (extract init attributes).
# 4.3.5. Executing PROC_ARST pass (detect async resets in processes).
# 4.3.6. Executing PROC_MUX pass (convert decision trees to multiplexers).
# 4.3.7. Executing PROC_DLATCH pass (convert process syncs to latches).
# 4.3.8. Executing PROC_DFF pass (convert process syncs to FFs).
# 4.3.9. Executing PROC_CLEAN pass (remove empty switches from decision trees).
# 4.4. Executing FLATTEN pass (flatten design).
# 4.5. Executing OPT_EXPR pass (perform const folding).
# 4.6. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.7. Executing CHECK pass (checking for obvious problems).
# 4.8. Executing OPT pass (performing simple optimizations).
# 4.8.1. Executing OPT_EXPR pass (perform const folding).
# 4.8.2. Executing OPT_MERGE pass (detect identical cells).
# 4.8.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.8.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.8.5. Executing OPT_MERGE pass (detect identical cells).
# 4.8.6. Executing OPT_DFF pass (perform DFF optimizations).
# 4.8.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.8.8. Executing OPT_EXPR pass (perform const folding).
# 4.8.9. Rerunning OPT passes. (Maybe there is more to do..)
# 4.8.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.8.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.8.12. Executing OPT_MERGE pass (detect identical cells).
# 4.8.13. Executing OPT_DFF pass (perform DFF optimizations).
# 4.8.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.8.15. Executing OPT_EXPR pass (perform const folding).
# 4.8.16. Finished OPT passes. (There is nothing left to do.)
# 4.9. Executing FSM pass (extract and optimize FSM).
# 4.9.1. Executing FSM_DETECT pass (finding FSMs in design).
# 4.9.2. Executing FSM_EXTRACT pass (extracting FSM from design).
# 4.9.3. Executing FSM_OPT pass (simple optimizations of FSMs).
# 4.9.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.9.5. Executing FSM_OPT pass (simple optimizations of FSMs).
# 4.9.6. Executing FSM_RECODE pass (re-assigning FSM state encoding).
# 4.9.7. Executing FSM_INFO pass (dumping all available information on FSM cells).
# 4.9.8. Executing FSM_MAP pass (mapping FSMs to basic logic).
# 4.10. Executing OPT pass (performing simple optimizations).
# 4.10.1. Executing OPT_EXPR pass (perform const folding).
# 4.10.2. Executing OPT_MERGE pass (detect identical cells).
# 4.10.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.10.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.10.5. Executing OPT_MERGE pass (detect identical cells).
# 4.10.6. Executing OPT_DFF pass (perform DFF optimizations).
# 4.10.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.10.8. Executing OPT_EXPR pass (perform const folding).
# 4.10.9. Rerunning OPT passes. (Maybe there is more to do..)
# 4.10.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.10.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.10.12. Executing OPT_MERGE pass (detect identical cells).
# 4.10.13. Executing OPT_DFF pass (perform DFF optimizations).
# 4.10.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.10.15. Executing OPT_EXPR pass (perform const folding).
# 4.10.16. Finished OPT passes. (There is nothing left to do.)
# 4.11. Executing WREDUCE pass (reducing word size of cells).
# 4.12. Executing PEEPOPT pass (run peephole optimizers).
# 4.13. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.14. Executing ALUMACC pass (create $alu and $macc cells).
# 4.15. Executing SHARE pass (SAT-based resource sharing).
# 4.16. Executing OPT pass (performing simple optimizations).
# 4.16.1. Executing OPT_EXPR pass (perform const folding).
# 4.16.2. Executing OPT_MERGE pass (detect identical cells).
# 4.16.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.16.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.16.5. Executing OPT_MERGE pass (detect identical cells).
# 4.16.6. Executing OPT_DFF pass (perform DFF optimizations).
# 4.16.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.16.8. Executing OPT_EXPR pass (perform const folding).
# 4.16.9. Rerunning OPT passes. (Maybe there is more to do..)
# 4.16.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.16.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.16.12. Executing OPT_MERGE pass (detect identical cells).
# 4.16.13. Executing OPT_DFF pass (perform DFF optimizations).
# 4.16.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.16.15. Executing OPT_EXPR pass (perform const folding).
# 4.16.16. Finished OPT passes. (There is nothing left to do.)
# 4.17. Executing MEMORY pass.
# 4.17.1. Executing OPT_MEM pass (optimize memories).
# 4.17.2. Executing MEMORY_DFF pass (merging $dff cells to $memrd and $memwr).
# 4.17.3. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.17.4. Executing MEMORY_SHARE pass (consolidating $memrd/$memwr cells).
# 4.17.5. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.17.6. Executing MEMORY_COLLECT pass (generating $mem cells).
# 4.18. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.19. Executing OPT pass (performing simple optimizations).
# 4.19.1. Executing OPT_EXPR pass (perform const folding).
# 4.19.2. Executing OPT_MERGE pass (detect identical cells).
# 4.19.3. Executing OPT_DFF pass (perform DFF optimizations).
# 4.19.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.19.5. Finished fast OPT passes.
# 4.20. Executing MEMORY_MAP pass (converting memories to logic and flip-flops).
# 4.21. Executing OPT pass (performing simple optimizations).
# 4.21.1. Executing OPT_EXPR pass (perform const folding).
# 4.21.2. Executing OPT_MERGE pass (detect identical cells).
# 4.21.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.21.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.21.5. Executing OPT_MERGE pass (detect identical cells).
# 4.21.6. Executing OPT_SHARE pass.
# 4.21.7. Executing OPT_DFF pass (perform DFF optimizations).
# 4.21.8. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.21.9. Executing OPT_EXPR pass (perform const folding).
# 4.21.10. Rerunning OPT passes. (Maybe there is more to do..)
# 4.21.11. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.21.12. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.21.13. Executing OPT_MERGE pass (detect identical cells).
# 4.21.14. Executing OPT_SHARE pass.
# 4.21.15. Executing OPT_DFF pass (perform DFF optimizations).
# 4.21.16. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.21.17. Executing OPT_EXPR pass (perform const folding).
# 4.21.18. Rerunning OPT passes. (Maybe there is more to do..)
# 4.21.19. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.21.20. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.21.21. Executing OPT_MERGE pass (detect identical cells).
# 4.21.22. Executing OPT_SHARE pass.
# 4.21.23. Executing OPT_DFF pass (perform DFF optimizations).
# 4.21.24. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.21.25. Executing OPT_EXPR pass (perform const folding).
# 4.21.26. Finished OPT passes. (There is nothing left to do.)
# 4.22. Executing TECHMAP pass (map to technology primitives).
# 4.22.1. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/tools/install/yosys/bin/../share/yosys/techmap.v
# 4.22.2. Continuing TECHMAP pass.
# 4.23. Executing OPT pass (performing simple optimizations).
# 4.23.1. Executing OPT_EXPR pass (perform const folding).
# 4.23.2. Executing OPT_MERGE pass (detect identical cells).
# 4.23.3. Executing OPT_DFF pass (perform DFF optimizations).
# 4.23.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.23.5. Rerunning OPT passes. (Removed registers in this run.)
# 4.23.6. Executing OPT_EXPR pass (perform const folding).
# 4.23.7. Executing OPT_MERGE pass (detect identical cells).
# 4.23.8. Executing OPT_DFF pass (perform DFF optimizations).
# 4.23.9. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.23.10. Rerunning OPT passes. (Removed registers in this run.)
# 4.23.11. Executing OPT_EXPR pass (perform const folding).
# 4.23.12. Executing OPT_MERGE pass (detect identical cells).
# 4.23.13. Executing OPT_DFF pass (perform DFF optimizations).
# 4.23.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.23.15. Finished fast OPT passes.
# 4.24. Executing ABC pass (technology mapping using ABC).
# 4.24.1. Extracting gate netlist of module `\main_kernel' to `<abc-temp-dir>/input.blif'..
# 4.25. Executing OPT pass (performing simple optimizations).
# 4.25.1. Executing OPT_EXPR pass (perform const folding).
# 4.25.2. Executing OPT_MERGE pass (detect identical cells).
# 4.25.3. Executing OPT_DFF pass (perform DFF optimizations).
# 4.25.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.25.5. Finished fast OPT passes.
# 4.26. Executing HIERARCHY pass (managing design hierarchy).
# 4.26.1. Analyzing design hierarchy..
# 4.26.2. Analyzing design hierarchy..
# 4.27. Printing statistics.
# 4.28. Executing CHECK pass (checking for obvious problems).
# 5. Executing OPT pass (performing simple optimizations).
# 5.1. Executing OPT_EXPR pass (perform const folding).
# 5.2. Executing OPT_MERGE pass (detect identical cells).
# 5.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 5.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 5.5. Executing OPT_MERGE pass (detect identical cells).
# 5.6. Executing OPT_DFF pass (perform DFF optimizations).
# 5.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 5.8. Executing OPT_EXPR pass (perform const folding).
# 5.9. Rerunning OPT passes. (Maybe there is more to do..)
# 5.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 5.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 5.12. Executing OPT_MERGE pass (detect identical cells).
# 5.13. Executing OPT_DFF pass (perform DFF optimizations).
# 5.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 5.15. Executing OPT_EXPR pass (perform const folding).
# 5.16. Finished OPT passes. (There is nothing left to do.)
# 6. Executing EXTRACT_FA pass (find and extract full/half adders).
# 7. Executing TECHMAP pass (map to technology primitives).
# 7.1. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/flow/platforms/nangate45/cells_adders.v
# 7.2. Continuing TECHMAP pass.
# 8. Executing TECHMAP pass (map to technology primitives).
# 8.1. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/tools/install/yosys/bin/../share/yosys/techmap.v
# 8.2. Continuing TECHMAP pass.
# 9. Executing OPT pass (performing simple optimizations).
# 9.1. Executing OPT_EXPR pass (perform const folding).
# 9.2. Executing OPT_MERGE pass (detect identical cells).
# 9.3. Executing OPT_DFF pass (perform DFF optimizations).
# 9.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 9.5. Finished fast OPT passes.
# 10. Executing TECHMAP pass (map to technology primitives).
# 10.1. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/flow/platforms/nangate45/cells_latch.v
# 10.2. Continuing TECHMAP pass.
# 11. Executing DFFLIBMAP pass (mapping DFF cells to sequential cells from liberty file).
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFRS_X1' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFRS_X2' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFR_X1' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFR_X2' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFS_X1' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFS_X2' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFF_X1' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFF_X2' - skipping.
# 11.1. Executing DFFLEGALIZE pass (convert FFs to types supported by the target).
# 12. Executing OPT pass (performing simple optimizations).
# 12.1. Executing OPT_EXPR pass (perform const folding).
# 12.2. Executing OPT_MERGE pass (detect identical cells).
# 12.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 12.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 12.5. Executing OPT_MERGE pass (detect identical cells).
# 12.6. Executing OPT_DFF pass (perform DFF optimizations).
# 12.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 12.8. Executing OPT_EXPR pass (perform const folding).
# 12.9. Rerunning OPT passes. (Maybe there is more to do..)
# 12.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 12.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 12.12. Executing OPT_MERGE pass (detect identical cells).
# 12.13. Executing OPT_DFF pass (perform DFF optimizations).
# 12.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 12.15. Executing OPT_EXPR pass (perform const folding).
# 12.16. Finished OPT passes. (There is nothing left to do.)
# Using ABC speed script.
# 13. Executing ABC pass (technology mapping using ABC).
# 13.1. Extracting gate netlist of module `\main_kernel' to `<abc-temp-dir>/input.blif'..
# 13.1.1. Executing ABC.
# 13.1.2. Re-integrating ABC results.
# 14. Executing SETUNDEF pass (replace undef values with defined constants).
# 15. Executing SPLITNETS pass (splitting up multi-bit signals).
# 16. Executing OPT_CLEAN pass (remove unused cells and wires).
# 17. Executing HILOMAP pass (mapping to constant drivers).
# 18. Executing INSBUF pass (insert buffer cells for connected wires).
# 19. Executing CHECK pass (checking for obvious problems).
# 20. Printing statistics.
# 21. Executing Verilog backend.
# Warnings: 8 unique messages, 72 total
# End of script. Logfile hash: e878d48e15, CPU: user 34.32s system 0.28s, MEM: 166.17 MB peak
# Yosys 0.9+3672 (git sha1 UNKNOWN, gcc 7.3.1 -fPIC -Os)
# Time spent: 34% 2x abc (17 sec), 14% 39x opt_clean (7 sec), ...
# Elapsed time: 0:51.64[h:]min:sec. CPU time: user 50.63 sys 0.98 (99%). Peak memory: 170164KB.
# mkdir -p /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/reports/nangate45/main_kernel/base
# cp /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/1_1_yosys.v /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/1_synth.v
# mkdir -p /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/reports/nangate45/main_kernel/base
# cp HLS_output/Synthesis/main_kernel.sdc /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/1_synth.sdc
# (/usr/bin/time -f 'Elapsed time: %E[h:]min:sec. CPU time: user %U sys %S (%P). Peak memory: %MKB.' /OpenROAD-flow-scripts/tools/install/OpenROAD/bin/openroad -exit -no_init  /OpenROAD-flow-scripts/flow/scripts/floorplan.tcl -metrics /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base/2_1_floorplan.json) 2>&1 | tee /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base/2_1_floorplan.log
# OpenROAD GITDIR-NOTFOUND
# This program is licensed under the BSD-3 license. See the LICENSE file for details.
# Components of this program may be licensed under more restrictive licenses which must be honored.
# [INFO ODB-0222] Reading LEF file: /OpenROAD-flow-scripts/flow/platforms/nangate45/lef/NangateOpenCellLibrary.tech.lef
# [INFO ODB-0223]     Created 22 technology layers
# [INFO ODB-0224]     Created 27 technology vias
# [INFO ODB-0226] Finished LEF file:  /OpenROAD-flow-scripts/flow/platforms/nangate45/lef/NangateOpenCellLibrary.tech.lef
# [INFO ODB-0222] Reading LEF file: /OpenROAD-flow-scripts/flow/platforms/nangate45/lef/NangateOpenCellLibrary.macro.mod.lef
# [INFO ODB-0225]     Created 135 library cells
# ...
#      5    8.71                           _12491_ (net)
#                   0.02    0.00    1.32 ^ _14609_/B1 (OAI22_X1)
#                   0.01    0.03    1.35 v _14609_/ZN (OAI22_X1)
#      2    3.24                           _07356_ (net)
#                   0.01    0.00    1.35 v _14611_/B (MUX2_X1)
#                   0.01    0.06    1.41 v _14611_/Z (MUX2_X1)
#      1    3.36                           _07358_ (net)
#                   0.01    0.00    1.41 v _14615_/B2 (OAI221_X2)
#                   0.04    0.06    1.47 ^ _14615_/ZN (OAI221_X2)
#      1    4.61                           _07362_ (net)
#                   0.04    0.00    1.47 ^ _14622_/A (OAI221_X2)
#                   0.04    0.07    1.53 v _14622_/ZN (OAI221_X2)
#      5   21.40                           _07369_ (net)
#                   0.04    0.00    1.54 v _14626_/B2 (OAI33_X1)
#                   0.09    0.12    1.66 ^ _14626_/ZN (OAI33_X1)
#      2    6.01                           _07373_ (net)
#                   0.09    0.00    1.66 ^ repeater309/A (CLKBUF_X2)
#                   0.02    0.06    1.71 ^ repeater309/Z (CLKBUF_X2)
#      4   11.79                           net309 (net)
#                   0.02    0.00    1.72 ^ repeater308/A (CLKBUF_X2)
#                   0.02    0.04    1.76 ^ repeater308/Z (CLKBUF_X2)
#      6   11.71                           net308 (net)
#                   0.02    0.00    1.76 ^ repeater306/A (BUF_X1)
#                   0.02    0.04    1.80 ^ repeater306/Z (BUF_X1)
#      5   10.04                           net306 (net)
#                   0.02    0.00    1.80 ^ repeater304/A (BUF_X1)
#                   0.02    0.04    1.85 ^ repeater304/Z (BUF_X1)
#      3    8.72                           net304 (net)
#                   0.02    0.00    1.85 ^ repeater303/A (CLKBUF_X2)
#                   0.01    0.04    1.89 ^ repeater303/Z (CLKBUF_X2)
#      2   10.39                           net303 (net)
#                   0.01    0.00    1.89 ^ _14634_/A2 (NOR3_X4)
#                   0.04    0.02    1.91 v _14634_/ZN (NOR3_X4)
#     13   36.02                           _07381_ (net)
#                   0.04    0.01    1.91 v _22576_/A3 (NAND3_X1)
#                   0.02    0.04    1.95 ^ _22576_/ZN (NAND3_X1)
#      1    3.21                           _06702_ (net)
#                   0.02    0.00    1.95 ^ _22580_/B2 (OAI222_X2)
#                   0.02    0.04    1.99 v _22580_/ZN (OAI222_X2)
#      1    3.89                           _06706_ (net)
#                   0.02    0.00    1.99 v _22584_/A (AOI221_X2)
#                   0.04    0.08    2.07 ^ _22584_/ZN (AOI221_X2)
#      1    3.64                           _06710_ (net)
#                   0.04    0.00    2.07 ^ _22585_/B (XNOR2_X1)
#                   0.03    0.05    2.12 ^ _22585_/ZN (XNOR2_X1)
#      1    4.14                           _12509_ (net)
#                   0.03    0.00    2.12 ^ _26263_/A (HA_X1)
#                   0.01    0.04    2.16 ^ _26263_/CO (HA_X1)
#      1    2.00                           _12508_ (net)
#                   0.01    0.00    2.16 ^ _23276_/A (INV_X1)
#                   0.01    0.01    2.17 v _23276_/ZN (INV_X1)
#      1    3.54                           _11089_ (net)
#                   0.01    0.00    2.17 v _25763_/B (FA_X1)
#                   0.02    0.08    2.25 v _25763_/CO (FA_X1)
#      2    6.19                           _11091_ (net)
#                   0.02    0.00    2.26 v _15070_/B2 (OAI21_X1)
#                   0.03    0.05    2.30 ^ _15070_/ZN (OAI21_X1)
#      1    3.72                           _02303_ (net)
#                   0.03    0.00    2.30 ^ _15071_/B1 (AOI21_X2)
#                   0.02    0.02    2.33 v _15071_/ZN (AOI21_X2)
#      3    8.31                           _11100_ (net)
#                   0.02    0.00    2.33 v _15074_/A1 (OR2_X1)
#                   0.01    0.05    2.37 v _15074_/ZN (OR2_X1)
#      1    0.98                           _02306_ (net)
#                   0.01    0.00    2.37 v _15075_/A2 (AND2_X1)
#                   0.01    0.04    2.41 v _15075_/ZN (AND2_X1)
#      2    5.50                           _11109_ (net)
#                   0.01    0.00    2.41 v _15079_/B2 (OAI21_X1)
#                   0.03    0.04    2.45 ^ _15079_/ZN (OAI21_X1)
#      2    4.19                           _02310_ (net)
#                   0.03    0.00    2.45 ^ _15080_/A (INV_X1)
#                   0.01    0.01    2.47 v _15080_/ZN (INV_X1)
#      1    3.04                           _11114_ (net)
#                   0.01    0.00    2.47 v _25768_/CI (FA_X1)
#                   0.02    0.07    2.54 v _25768_/CO (FA_X1)
#      1    4.64                           _11115_ (net)
#                   0.02    0.00    2.54 v _15107_/B (XOR2_X2)
#                   0.02    0.06    2.60 v _15107_/Z (XOR2_X2)
#      2    6.40                           _02332_ (net)
#                   0.02    0.00    2.60 v _15108_/A2 (OR2_X1)
#                   0.01    0.05    2.66 v _15108_/ZN (OR2_X1)
#      1    1.77                           _02333_ (net)
#                   0.01    0.00    2.66 v _15109_/A4 (OR4_X2)
#                   0.02    0.12    2.78 v _15109_/ZN (OR4_X2)
#      4    8.44                           _02334_ (net)
#                   0.02    0.00    2.78 v _15144_/A1 (NOR4_X2)
#                   0.05    0.06    2.84 ^ _15144_/ZN (NOR4_X2)
#      2    5.27                           _12588_ (net)
#                   0.05    0.00    2.84 ^ _15146_/A2 (AND3_X1)
#                   0.02    0.07    2.91 ^ _15146_/ZN (AND3_X1)
#      3    7.84                           _12594_ (net)
#                   0.02    0.00    2.91 ^ _15149_/A1 (AND2_X1)
#                   0.01    0.04    2.95 ^ _15149_/ZN (AND2_X1)
#      2    4.76                           _12604_ (net)
#                   0.01    0.00    2.95 ^ _15152_/A1 (AND2_X1)
#                   0.01    0.04    2.99 ^ _15152_/ZN (AND2_X1)
#      1    3.85                           _12616_ (net)
#                   0.01    0.00    2.99 ^ _26291_/B (HA_X1)
#                   0.01    0.03    3.03 ^ _26291_/CO (HA_X1)
#      1    2.33                           _12617_ (net)
#                   0.01    0.00    3.03 ^ _15158_/A (XOR2_X1)
#                   0.03    0.06    3.08 ^ _15158_/Z (XOR2_X1)
#      2    4.07                           _02372_ (net)
#                   0.03    0.00    3.08 ^ _15160_/A3 (AND4_X1)
#                   0.01    0.06    3.15 ^ _15160_/ZN (AND4_X1)
#      1    1.95                           _02374_ (net)
#                   0.01    0.00    3.15 ^ _15161_/A2 (AND2_X2)
#                   0.02    0.04    3.19 ^ _15161_/ZN (AND2_X2)
#      5   13.18                           _02375_ (net)
#                   0.02    0.00    3.19 ^ _15168_/A1 (AND3_X1)
#                   0.03    0.07    3.26 ^ _15168_/ZN (AND3_X1)
#      4   10.57                           _02382_ (net)
#                   0.03    0.00    3.26 ^ _15189_/A (OAI21_X2)
#                   0.01    0.03    3.29 v _15189_/ZN (OAI21_X2)
#      2    7.91                           _02402_ (net)
#                   0.01    0.00    3.29 v _15190_/A3 (NAND3_X4)
#                   0.02    0.03    3.32 ^ _15190_/ZN (NAND3_X4)
#     11   25.58                           _02403_ (net)
#                   0.02    0.00    3.32 ^ _16006_/S (MUX2_X1)
#                   0.01    0.06    3.38 v _16006_/Z (MUX2_X1)
#      1    1.99                           _03077_ (net)
#                   0.01    0.00    3.38 v _16007_/A2 (NOR2_X1)
#                   0.02    0.04    3.42 ^ _16007_/ZN (NOR2_X1)
#      1    3.03                           _main_kernel_i0.Datapath_i.__float_adde8m23b_127rnh_106_i0.Datapath_i.fu___float_adde8m23b_127rnh_495477_496085.out1[9] (net)
#                   0.02    0.00    3.42 ^ _23346_/D (DFF_X1)
#                                   3.42   data arrival time
#
#                           5.00    5.00   clock clock (rise edge)
#                           0.00    5.00   clock source latency
#                   0.00    0.00    5.00 ^ clock (in)
#      1   17.63                           clock (net)
#                   0.01    0.00    5.00 ^ repeater1/A (BUF_X8)
#                   0.01    0.02    5.03 ^ repeater1/Z (BUF_X8)
#      1   46.72                           net515 (net)
#                   0.06    0.05    5.07 ^ clkbuf_0_clock/A (BUF_X4)
#                   0.03    0.05    5.12 ^ clkbuf_0_clock/Z (BUF_X4)
#      4   55.44                           clknet_0_clock (net)
#                   0.03    0.01    5.13 ^ clkbuf_2_2_0_clock/A (BUF_X4)
#                   0.02    0.04    5.17 ^ clkbuf_2_2_0_clock/Z (BUF_X4)
#      2   23.30                           clknet_2_2_0_clock (net)
#                   0.02    0.00    5.17 ^ clkbuf_3_5__f_clock/A (BUF_X4)
#                   0.05    0.07    5.24 ^ clkbuf_3_5__f_clock/Z (BUF_X4)
#     13   86.26                           clknet_3_5__leaf_clock (net)
#                   0.05    0.01    5.24 ^ clkbuf_leaf_17_clock/A (BUF_X4)
#                   0.03    0.05    5.29 ^ clkbuf_leaf_17_clock/Z (BUF_X4)
#     30   47.06                           clknet_leaf_17_clock (net)
#                   0.03    0.00    5.30 ^ _23346_/CK (DFF_X1)
#                           0.00    5.30   clock reconvergence pessimism
#                          -0.03    5.26   library setup time
#                                   5.26   data required time
# -----------------------------------------------------------------------------
#                                   5.26   data required time
#                                  -3.42   data arrival time
# -----------------------------------------------------------------------------
#                                   1.85   slack (MET)
#
#
#
# ==========================================================================
# finish report_check_types -max_slew -max_cap -max_fanout -violators
# --------------------------------------------------------------------------
# max capacitance
#
# Pin                                    Limit     Cap   Slack
# ------------------------------------------------------------
# _14572_/ZN                             52.03   53.59   -1.56 (VIOLATED)
# _14777_/ZN                            106.81  107.37   -0.56 (VIOLATED)
#
#
# ==========================================================================
# finish max_slew_violation_count
# --------------------------------------------------------------------------
# max slew violation count 0
#
# ==========================================================================
# finish max_fanout_violation_count
# --------------------------------------------------------------------------
# max fanout violation count 0
#
# ==========================================================================
# finish max_cap_violation_count
# --------------------------------------------------------------------------
# max cap violation count 2
#
# ==========================================================================
# finish report_tns
# --------------------------------------------------------------------------
# tns 0.00
#
# ==========================================================================
# finish report_wns
# --------------------------------------------------------------------------
# wns 0.00
#
# ==========================================================================
# finish report_worst_slack
# --------------------------------------------------------------------------
# worst slack 1.85
#
# ==========================================================================
# finish report_clock_skew
# --------------------------------------------------------------------------
# Clock clock
# Latency      CRPR       Skew
# _23355_/CK ^
#    0.31
# _23338_/CK ^
#    0.23      0.00       0.08
#
#
# ==========================================================================
# finish report_power
# --------------------------------------------------------------------------
# Group                  Internal  Switching    Leakage      Total
#                           Power      Power      Power      Power
# ----------------------------------------------------------------
# Sequential             2.16e-03   4.32e-04   1.69e-04   2.76e-03  43.0%
# Combinational          1.35e-03   1.88e-03   4.31e-04   3.66e-03  57.0%
# Macro                  0.00e+00   0.00e+00   0.00e+00   0.00e+00   0.0%
# Pad                    0.00e+00   0.00e+00   0.00e+00   0.00e+00   0.0%
# ----------------------------------------------------------------
# Total                  3.51e-03   2.31e-03   6.00e-04   6.42e-03 100.0%
#                           54.6%      36.0%       9.3%
#
# ==========================================================================
# finish report_design_area
# --------------------------------------------------------------------------
# Design area 28904 u^2 2% utilization.
#
# [WARNING GUI-0010] File path does not end with a valid extension, new path is: /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/reports/nangate45/main_kernel/base/final.webp.png
# Elapsed time: 0:15.24[h:]min:sec. CPU time: user 14.84 sys 0.37 (99%). Peak memory: 623376KB.
# cp /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/5_route.sdc /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.sdc
# sed '/OR_DEFAULT/d' /OpenROAD-flow-scripts/flow/platforms/nangate45/lef/NangateOpenCellLibrary.tech.lef > /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/klayout_tech.lef
# sed 's,<lef-files>.*</lef-files>,<lef-files>/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/klayout_tech.lef</lef-files> <lef-files>/OpenROAD-flow-scripts/flow/platforms/nangate45/lef/NangateOpenCellLibrary.macro.mod.lef</lef-files>,g' /OpenROAD-flow-scripts/flow/platforms/nangate45/FreePDK45.lyt > /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/klayout.lyt
# (/usr/bin/time -f 'Elapsed time: %E[h:]min:sec. CPU time: user %U sys %S (%P). Peak memory: %MKB.' stdbuf -o L /usr/bin/klayout -zz -rd design_name=main_kernel \
#         -rd in_def=/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.def \
#         -rd in_files="/OpenROAD-flow-scripts/flow/platforms/nangate45/gds/NangateOpenCellLibrary.gds  " \
#         -rd config_file= \
#         -rd seal_file="" \
#         -rd out_file=/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_1_merged.gds \
#         -rd tech_file=/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/klayout.lyt \
#         -rm /OpenROAD-flow-scripts/flow/util/def2stream.py) 2>&1 | tee /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base/6_1_merge.log
# [INFO] Reporting cells prior to loading DEF ...
# [INFO] Reading DEF ...
# [INFO] Clearing cells...
# [INFO] ... preserving 'VIA_via6_960x2800'
# [INFO] ... preserving 'VIA_via5_960x2800'
# [INFO] ... preserving 'VIA_via4_960x2800'
# [INFO] ... preserving 'VIA_via3_960x340'
# [INFO] ... preserving 'VIA_via2_960x340'
# [INFO] ... preserving 'VIA_via1_960x340'
# [INFO] ... preserving 'VIA_via1_4'
# [INFO] ... preserving 'VIA_via2_5'
# [INFO] ... preserving 'VIA_via1_7'
# [INFO] ... preserving 'VIA_via3_2'
# [INFO] ... preserving 'VIA_via4_0'
# [INFO] ... preserving 'VIA_via5_0'
# [INFO] ... preserving 'VIA_via6_0'
# [INFO] Merging GDS/OAS files...
# 	/OpenROAD-flow-scripts/flow/platforms/nangate45/gds/NangateOpenCellLibrary.gds
# [INFO] Copying toplevel cell 'main_kernel'
# WARNING: no fill config file specified
# [INFO] Checking for missing cell from GDS/OAS...
# [INFO] All LEF cells have matching GDS/OAS cells
# [INFO] Checking for orphan cell in the final layout...
# [INFO] No orphan cells
# [INFO] Writing out GDS/OAS '/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_1_merged.gds'
# Elapsed time: 0:07.38[h:]min:sec. CPU time: user 6.88 sys 0.36 (98%). Peak memory: 683680KB.
# cp /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_1_merged.gds /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.gds
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version

# %% [markdown]
# ### Optimized kernel

# %%
! scripts/run-openroad.sh optimized

# Approx. 23min to execute
# Out:
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version/output/optimized /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version
# [INFO][FLOW] Using platform directory /OpenROAD-flow-scripts/flow/platforms/nangate45
# /OpenROAD-flow-scripts/flow/util/markDontUse.py -p "TAPCELL_X1 FILLCELL_X1 AOI211_X1 OAI211_X1" -i /OpenROAD-flow-scripts/flow/platforms/nangate45/lib/NangateOpenCellLibrary_typical.lib -o /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/lib/NangateOpenCellLibrary_typical.lib
# Opening file for replace: /OpenROAD-flow-scripts/flow/platforms/nangate45/lib/NangateOpenCellLibrary_typical.lib
# Marked 4 cells as dont_use
# Commented 0 lines containing "original_pin"
# Writing replaced file: /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/lib/NangateOpenCellLibrary_typical.lib
# mkdir -p /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/reports/nangate45/main_kernel/base
# (/usr/bin/time -f 'Elapsed time: %E[h:]min:sec. CPU time: user %U sys %S (%P). Peak memory: %MKB.' /OpenROAD-flow-scripts/tools/install/yosys/bin/yosys -v 3 -c /OpenROAD-flow-scripts/flow/scripts/synth.tcl) 2>&1 | tee /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base/1_1_yosys.log
# 1. Executing Verilog-2005 frontend: ./main_kernel.v
# 2. Executing Liberty frontend.
# 3. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/flow/platforms/nangate45/cells_clkgate.v
# 4. Executing SYNTH pass.
# 4.1. Executing HIERARCHY pass (managing design hierarchy).
# 4.2. Executing AST frontend in derive mode using pre-parsed AST for module `\main_kernel'.
# 4.2.1. Analyzing design hierarchy..
# 4.2.2. Executing AST frontend in derive mode using pre-parsed AST for module `\_main_kernel'.
# 4.2.3. Analyzing design hierarchy..
# 4.2.4. Executing AST frontend in derive mode using pre-parsed AST for module `\flipflop_AR'.
# 4.2.5. Executing AST frontend in derive mode using pre-parsed AST for module `\datapath_main_kernel'.
# 4.2.6. Executing AST frontend in derive mode using pre-parsed AST for module `\controller_main_kernel'.
# 4.2.7. Analyzing design hierarchy..
# 4.2.8. Executing AST frontend in derive mode using pre-parsed AST for module `\split_signal'.
# 4.2.9. Executing AST frontend in derive mode using pre-parsed AST for module `\split_signal'.
# 4.2.10. Executing AST frontend in derive mode using pre-parsed AST for module `\split_signal'.
# 4.2.11. Executing AST frontend in derive mode using pre-parsed AST for module `\register_SE'.
# 4.2.12. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.13. Executing AST frontend in derive mode using pre-parsed AST for module `\register_SE'.
# 4.2.14. Executing AST frontend in derive mode using pre-parsed AST for module `\register_SE'.
# 4.2.15. Executing AST frontend in derive mode using pre-parsed AST for module `\join_signal'.
# 4.2.16. Executing AST frontend in derive mode using pre-parsed AST for module `\join_signal'.
# 4.2.17. Executing AST frontend in derive mode using pre-parsed AST for module `\join_signal'.
# 4.2.18. Executing AST frontend in derive mode using pre-parsed AST for module `\truth_and_expr_FU'.
# 4.2.19. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.20. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lt_expr_FU'.
# 4.2.21. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.22. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.23. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.24. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_view_convert_expr_FU'.
# 4.2.25. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.26. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.27. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.28. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.29. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.30. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.31. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.32. Executing AST frontend in derive mode using pre-parsed AST for module `\addr_expr_FU'.
# 4.2.33. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.34. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.35. Executing AST frontend in derive mode using pre-parsed AST for module `\read_cond_FU'.
# 4.2.36. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.37. Executing AST frontend in derive mode using pre-parsed AST for module `\__float_mule8m23b_127rnh'.
# 4.2.38. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_pointer_plus_expr_FU'.
# 4.2.39. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.40. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.41. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.42. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.43. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.44. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.45. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.46. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.47. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.48. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.49. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.50. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.51. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.52. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.53. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.54. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.55. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.56. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.57. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.58. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.59. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.60. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.61. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.62. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.63. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.64. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.65. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.66. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.67. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.68. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.69. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.70. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.71. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.72. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.73. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.74. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.75. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.76. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.77. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.78. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.79. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.80. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.81. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.82. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.83. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.84. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.85. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.86. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.87. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.88. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.89. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.90. Executing AST frontend in derive mode using pre-parsed AST for module `\bus_merger'.
# 4.2.91. Executing AST frontend in derive mode using pre-parsed AST for module `\bus_merger'.
# 4.2.92. Executing AST frontend in derive mode using pre-parsed AST for module `\bus_merger'.
# 4.2.93. Executing AST frontend in derive mode using pre-parsed AST for module `\ARRAY_1D_STD_BRAM_NN_SDS'.
# 4.2.94. Executing AST frontend in derive mode using pre-parsed AST for module `\ARRAY_1D_STD_BRAM_NN_SDS'.
# 4.2.95. Executing AST frontend in derive mode using pre-parsed AST for module `\ARRAY_1D_STD_BRAM_NN_SDS'.
# 4.2.96. Executing AST frontend in derive mode using pre-parsed AST for module `\__float_adde8m23b_127rnh'.
# 4.2.97. Executing AST frontend in derive mode using pre-parsed AST for module `\MUX_GATE'.
# 4.2.98. Executing AST frontend in derive mode using pre-parsed AST for module `\MUX_GATE'.
# 4.2.99. Executing AST frontend in derive mode using pre-parsed AST for module `\BMEMORY_CTRLN'.
# 4.2.100. Executing AST frontend in derive mode using pre-parsed AST for module `\ASSIGN_VECTOR_BOOL_FU'.
# 4.2.101. Executing AST frontend in derive mode using pre-parsed AST for module `\ASSIGN_UNSIGNED_FU'.
# 4.2.102. Analyzing design hierarchy..
# 4.2.103. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.104. Executing AST frontend in derive mode using pre-parsed AST for module `\datapath___float_adde8m23b_127rnh'.
# 4.2.105. Executing AST frontend in derive mode using pre-parsed AST for module `\controller___float_adde8m23b_127rnh'.
# 4.2.106. Executing AST frontend in derive mode using pre-parsed AST for module `\datapath___float_mule8m23b_127rnh'.
# 4.2.107. Executing AST frontend in derive mode using pre-parsed AST for module `\controller___float_mule8m23b_127rnh'.
# 4.2.108. Executing AST frontend in derive mode using pre-parsed AST for module `\ARRAY_1D_STD_BRAM_NN_SDS_BASE'.
# 4.2.109. Executing AST frontend in derive mode using pre-parsed AST for module `\ARRAY_1D_STD_BRAM_NN_SDS_BASE'.
# 4.2.110. Executing AST frontend in derive mode using pre-parsed AST for module `\ARRAY_1D_STD_BRAM_NN_SDS_BASE'.
# 4.2.111. Analyzing design hierarchy..
# 4.2.112. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.113. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.114. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.115. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.116. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.117. Executing AST frontend in derive mode using pre-parsed AST for module `\truth_or_expr_FU'.
# 4.2.118. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.119. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.120. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.121. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.122. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.123. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.124. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.125. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_extract_bit_expr_FU'.
# 4.2.126. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.127. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.128. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.129. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.130. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.131. Executing AST frontend in derive mode using pre-parsed AST for module `\truth_xor_expr_FU'.
# 4.2.132. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.133. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ne_expr_FU'.
# 4.2.134. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.135. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ne_expr_FU'.
# 4.2.136. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.137. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.138. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.139. Executing AST frontend in derive mode using pre-parsed AST for module `\UIdata_converter_FU'.
# 4.2.140. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.141. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.142. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.143. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.144. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.145. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.146. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.147. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.148. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.149. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.150. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.151. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.152. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.153. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.154. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.155. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.156. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_xor_expr_FU'.
# 4.2.157. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.158. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.159. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_xor_expr_FU'.
# 4.2.160. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.161. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.162. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.163. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.164. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.165. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.166. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.167. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.168. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.169. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.170. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.171. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.172. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.173. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_mult_expr_FU'.
# 4.2.174. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.175. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.176. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.177. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.178. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.179. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.180. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.181. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.182. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ternary_plus_expr_FU'.
# 4.2.183. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.184. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.185. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.186. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.187. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.188. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.189. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.190. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.191. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.192. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.193. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.194. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.195. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.196. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.197. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.198. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.199. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.200. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.201. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.202. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.203. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.204. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.205. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.206. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.207. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.208. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.209. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.210. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.211. Executing AST frontend in derive mode using pre-parsed AST for module `\register_STD'.
# 4.2.212. Executing AST frontend in derive mode using pre-parsed AST for module `\ASSIGN_UNSIGNED_FU'.
# 4.2.213. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.214. Executing AST frontend in derive mode using pre-parsed AST for module `\truth_not_expr_FU'.
# 4.2.215. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.216. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.217. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.218. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.219. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.220. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.221. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.222. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.223. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.224. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.225. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.226. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.227. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.228. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.229. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.230. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.231. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.232. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.233. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.234. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.235. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.236. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.237. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.238. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lt_expr_FU'.
# 4.2.239. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.240. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.241. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_eq_expr_FU'.
# 4.2.242. Executing AST frontend in derive mode using pre-parsed AST for module `\UIdata_converter_FU'.
# 4.2.243. Executing AST frontend in derive mode using pre-parsed AST for module `\lshift_expr_FU'.
# 4.2.244. Executing AST frontend in derive mode using pre-parsed AST for module `\lshift_expr_FU'.
# 4.2.245. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.246. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.247. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ne_expr_FU'.
# 4.2.248. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.249. Executing AST frontend in derive mode using pre-parsed AST for module `\UIdata_converter_FU'.
# 4.2.250. Executing AST frontend in derive mode using pre-parsed AST for module `\IUdata_converter_FU'.
# 4.2.251. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.252. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ne_expr_FU'.
# 4.2.253. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lt_expr_FU'.
# 4.2.254. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.255. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.256. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.257. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.258. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.259. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.260. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.261. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.262. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.263. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.264. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.265. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.266. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.267. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.268. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.269. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.270. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_ternary_pm_expr_FU'.
# 4.2.271. Executing AST frontend in derive mode using pre-parsed AST for module `\UUdata_converter_FU'.
# 4.2.272. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.273. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.274. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.275. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.276. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.277. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.278. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.279. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.280. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.281. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.282. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.283. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.284. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.285. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.286. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.287. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.288. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.289. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_plus_expr_FU'.
# 4.2.290. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_concat_expr_FU'.
# 4.2.291. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_xor_expr_FU'.
# 4.2.292. Executing AST frontend in derive mode using pre-parsed AST for module `\IIdata_converter_FU'.
# 4.2.293. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.294. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.295. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.296. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_xor_expr_FU'.
# 4.2.297. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.298. Executing AST frontend in derive mode using pre-parsed AST for module `\rshift_expr_FU'.
# 4.2.299. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.300. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.301. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.302. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_rshift_expr_FU'.
# 4.2.303. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_lshift_expr_FU'.
# 4.2.304. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_cond_expr_FU'.
# 4.2.305. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_minus_expr_FU'.
# 4.2.306. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_and_expr_FU'.
# 4.2.307. Executing AST frontend in derive mode using pre-parsed AST for module `\ui_bit_ior_expr_FU'.
# 4.2.308. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.309. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.310. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.311. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.312. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.313. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.314. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.315. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.316. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.317. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.318. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.319. Executing AST frontend in derive mode using pre-parsed AST for module `\constant_value'.
# 4.2.320. Analyzing design hierarchy..
# 4.2.321. Analyzing design hierarchy..
# 4.3. Executing PROC pass (convert processes to netlists).
# 4.3.1. Executing PROC_CLEAN pass (remove empty switches from decision trees).
# 4.3.2. Executing PROC_RMDEAD pass (remove dead branches from decision trees).
# 4.3.3. Executing PROC_PRUNE pass (remove redundant assignments in processes).
# 4.3.4. Executing PROC_INIT pass (extract init attributes).
# 4.3.5. Executing PROC_ARST pass (detect async resets in processes).
# 4.3.6. Executing PROC_MUX pass (convert decision trees to multiplexers).
# 4.3.7. Executing PROC_DLATCH pass (convert process syncs to latches).
# 4.3.8. Executing PROC_DFF pass (convert process syncs to FFs).
# 4.3.9. Executing PROC_CLEAN pass (remove empty switches from decision trees).
# 4.4. Executing FLATTEN pass (flatten design).
# 4.5. Executing OPT_EXPR pass (perform const folding).
# 4.6. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.7. Executing CHECK pass (checking for obvious problems).
# 4.8. Executing OPT pass (performing simple optimizations).
# 4.8.1. Executing OPT_EXPR pass (perform const folding).
# 4.8.2. Executing OPT_MERGE pass (detect identical cells).
# 4.8.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.8.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.8.5. Executing OPT_MERGE pass (detect identical cells).
# 4.8.6. Executing OPT_DFF pass (perform DFF optimizations).
# 4.8.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.8.8. Executing OPT_EXPR pass (perform const folding).
# 4.8.9. Rerunning OPT passes. (Maybe there is more to do..)
# 4.8.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.8.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.8.12. Executing OPT_MERGE pass (detect identical cells).
# 4.8.13. Executing OPT_DFF pass (perform DFF optimizations).
# 4.8.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.8.15. Executing OPT_EXPR pass (perform const folding).
# 4.8.16. Finished OPT passes. (There is nothing left to do.)
# 4.9. Executing FSM pass (extract and optimize FSM).
# 4.9.1. Executing FSM_DETECT pass (finding FSMs in design).
# 4.9.2. Executing FSM_EXTRACT pass (extracting FSM from design).
# 4.9.3. Executing FSM_OPT pass (simple optimizations of FSMs).
# 4.9.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.9.5. Executing FSM_OPT pass (simple optimizations of FSMs).
# 4.9.6. Executing FSM_RECODE pass (re-assigning FSM state encoding).
# 4.9.7. Executing FSM_INFO pass (dumping all available information on FSM cells).
# 4.9.8. Executing FSM_MAP pass (mapping FSMs to basic logic).
# 4.10. Executing OPT pass (performing simple optimizations).
# 4.10.1. Executing OPT_EXPR pass (perform const folding).
# 4.10.2. Executing OPT_MERGE pass (detect identical cells).
# 4.10.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.10.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.10.5. Executing OPT_MERGE pass (detect identical cells).
# 4.10.6. Executing OPT_DFF pass (perform DFF optimizations).
# 4.10.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.10.8. Executing OPT_EXPR pass (perform const folding).
# 4.10.9. Rerunning OPT passes. (Maybe there is more to do..)
# 4.10.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.10.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.10.12. Executing OPT_MERGE pass (detect identical cells).
# 4.10.13. Executing OPT_DFF pass (perform DFF optimizations).
# 4.10.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.10.15. Executing OPT_EXPR pass (perform const folding).
# 4.10.16. Rerunning OPT passes. (Maybe there is more to do..)
# 4.10.17. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.10.18. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.10.19. Executing OPT_MERGE pass (detect identical cells).
# 4.10.20. Executing OPT_DFF pass (perform DFF optimizations).
# 4.10.21. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.10.22. Executing OPT_EXPR pass (perform const folding).
# 4.10.23. Rerunning OPT passes. (Maybe there is more to do..)
# 4.10.24. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.10.25. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.10.26. Executing OPT_MERGE pass (detect identical cells).
# 4.10.27. Executing OPT_DFF pass (perform DFF optimizations).
# 4.10.28. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.10.29. Executing OPT_EXPR pass (perform const folding).
# 4.10.30. Finished OPT passes. (There is nothing left to do.)
# 4.11. Executing WREDUCE pass (reducing word size of cells).
# 4.12. Executing PEEPOPT pass (run peephole optimizers).
# 4.13. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.14. Executing ALUMACC pass (create $alu and $macc cells).
# 4.15. Executing SHARE pass (SAT-based resource sharing).
# 4.16. Executing OPT pass (performing simple optimizations).
# 4.16.1. Executing OPT_EXPR pass (perform const folding).
# 4.16.2. Executing OPT_MERGE pass (detect identical cells).
# 4.16.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.16.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.16.5. Executing OPT_MERGE pass (detect identical cells).
# 4.16.6. Executing OPT_DFF pass (perform DFF optimizations).
# 4.16.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.16.8. Executing OPT_EXPR pass (perform const folding).
# 4.16.9. Rerunning OPT passes. (Maybe there is more to do..)
# 4.16.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.16.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.16.12. Executing OPT_MERGE pass (detect identical cells).
# 4.16.13. Executing OPT_DFF pass (perform DFF optimizations).
# 4.16.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.16.15. Executing OPT_EXPR pass (perform const folding).
# 4.16.16. Rerunning OPT passes. (Maybe there is more to do..)
# 4.16.17. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.16.18. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.16.19. Executing OPT_MERGE pass (detect identical cells).
# 4.16.20. Executing OPT_DFF pass (perform DFF optimizations).
# 4.16.21. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.16.22. Executing OPT_EXPR pass (perform const folding).
# 4.16.23. Finished OPT passes. (There is nothing left to do.)
# 4.17. Executing MEMORY pass.
# 4.17.1. Executing OPT_MEM pass (optimize memories).
# 4.17.2. Executing MEMORY_DFF pass (merging $dff cells to $memrd and $memwr).
# 4.17.3. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.17.4. Executing MEMORY_SHARE pass (consolidating $memrd/$memwr cells).
# 4.17.5. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.17.6. Executing MEMORY_COLLECT pass (generating $mem cells).
# 4.18. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.19. Executing OPT pass (performing simple optimizations).
# 4.19.1. Executing OPT_EXPR pass (perform const folding).
# 4.19.2. Executing OPT_MERGE pass (detect identical cells).
# 4.19.3. Executing OPT_DFF pass (perform DFF optimizations).
# 4.19.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.19.5. Finished fast OPT passes.
# 4.20. Executing MEMORY_MAP pass (converting memories to logic and flip-flops).
# 4.21. Executing OPT pass (performing simple optimizations).
# 4.21.1. Executing OPT_EXPR pass (perform const folding).
# 4.21.2. Executing OPT_MERGE pass (detect identical cells).
# 4.21.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.21.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.21.5. Executing OPT_MERGE pass (detect identical cells).
# 4.21.6. Executing OPT_SHARE pass.
# 4.21.7. Executing OPT_DFF pass (perform DFF optimizations).
# 4.21.8. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.21.9. Executing OPT_EXPR pass (perform const folding).
# 4.21.10. Rerunning OPT passes. (Maybe there is more to do..)
# 4.21.11. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.21.12. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.21.13. Executing OPT_MERGE pass (detect identical cells).
# 4.21.14. Executing OPT_SHARE pass.
# 4.21.15. Executing OPT_DFF pass (perform DFF optimizations).
# 4.21.16. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.21.17. Executing OPT_EXPR pass (perform const folding).
# 4.21.18. Rerunning OPT passes. (Maybe there is more to do..)
# 4.21.19. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.21.20. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.21.21. Executing OPT_MERGE pass (detect identical cells).
# 4.21.22. Executing OPT_SHARE pass.
# 4.21.23. Executing OPT_DFF pass (perform DFF optimizations).
# 4.21.24. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.21.25. Executing OPT_EXPR pass (perform const folding).
# 4.21.26. Rerunning OPT passes. (Maybe there is more to do..)
# 4.21.27. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 4.21.28. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 4.21.29. Executing OPT_MERGE pass (detect identical cells).
# 4.21.30. Executing OPT_SHARE pass.
# 4.21.31. Executing OPT_DFF pass (perform DFF optimizations).
# 4.21.32. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.21.33. Executing OPT_EXPR pass (perform const folding).
# 4.21.34. Finished OPT passes. (There is nothing left to do.)
# 4.22. Executing TECHMAP pass (map to technology primitives).
# 4.22.1. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/tools/install/yosys/bin/../share/yosys/techmap.v
# 4.22.2. Continuing TECHMAP pass.
# 4.23. Executing OPT pass (performing simple optimizations).
# 4.23.1. Executing OPT_EXPR pass (perform const folding).
# 4.23.2. Executing OPT_MERGE pass (detect identical cells).
# 4.23.3. Executing OPT_DFF pass (perform DFF optimizations).
# 4.23.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.23.5. Rerunning OPT passes. (Removed registers in this run.)
# 4.23.6. Executing OPT_EXPR pass (perform const folding).
# 4.23.7. Executing OPT_MERGE pass (detect identical cells).
# 4.23.8. Executing OPT_DFF pass (perform DFF optimizations).
# 4.23.9. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.23.10. Rerunning OPT passes. (Removed registers in this run.)
# 4.23.11. Executing OPT_EXPR pass (perform const folding).
# 4.23.12. Executing OPT_MERGE pass (detect identical cells).
# 4.23.13. Executing OPT_DFF pass (perform DFF optimizations).
# 4.23.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.23.15. Finished fast OPT passes.
# 4.24. Executing ABC pass (technology mapping using ABC).
# 4.24.1. Extracting gate netlist of module `\main_kernel' to `<abc-temp-dir>/input.blif'..
# 4.25. Executing OPT pass (performing simple optimizations).
# 4.25.1. Executing OPT_EXPR pass (perform const folding).
# 4.25.2. Executing OPT_MERGE pass (detect identical cells).
# 4.25.3. Executing OPT_DFF pass (perform DFF optimizations).
# 4.25.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 4.25.5. Finished fast OPT passes.
# 4.26. Executing HIERARCHY pass (managing design hierarchy).
# 4.26.1. Analyzing design hierarchy..
# 4.26.2. Analyzing design hierarchy..
# 4.27. Printing statistics.
# 4.28. Executing CHECK pass (checking for obvious problems).
# 5. Executing OPT pass (performing simple optimizations).
# 5.1. Executing OPT_EXPR pass (perform const folding).
# 5.2. Executing OPT_MERGE pass (detect identical cells).
# 5.3. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 5.4. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 5.5. Executing OPT_MERGE pass (detect identical cells).
# 5.6. Executing OPT_DFF pass (perform DFF optimizations).
# 5.7. Executing OPT_CLEAN pass (remove unused cells and wires).
# 5.8. Executing OPT_EXPR pass (perform const folding).
# 5.9. Rerunning OPT passes. (Maybe there is more to do..)
# 5.10. Executing OPT_MUXTREE pass (detect dead branches in mux trees).
# 5.11. Executing OPT_REDUCE pass (consolidate $*mux and $reduce_* inputs).
# 5.12. Executing OPT_MERGE pass (detect identical cells).
# 5.13. Executing OPT_DFF pass (perform DFF optimizations).
# 5.14. Executing OPT_CLEAN pass (remove unused cells and wires).
# 5.15. Executing OPT_EXPR pass (perform const folding).
# 5.16. Finished OPT passes. (There is nothing left to do.)
# 6. Executing EXTRACT_FA pass (find and extract full/half adders).
# 7. Executing TECHMAP pass (map to technology primitives).
# 7.1. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/flow/platforms/nangate45/cells_adders.v
# 7.2. Continuing TECHMAP pass.
# 8. Executing TECHMAP pass (map to technology primitives).
# 8.1. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/tools/install/yosys/bin/../share/yosys/techmap.v
# 8.2. Continuing TECHMAP pass.
# 9. Executing OPT pass (performing simple optimizations).
# 9.1. Executing OPT_EXPR pass (perform const folding).
# 9.2. Executing OPT_MERGE pass (detect identical cells).
# 9.3. Executing OPT_DFF pass (perform DFF optimizations).
# 9.4. Executing OPT_CLEAN pass (remove unused cells and wires).
# 9.5. Finished fast OPT passes.
# 10. Executing TECHMAP pass (map to technology primitives).
# 10.1. Executing Verilog-2005 frontend: /OpenROAD-flow-scripts/flow/platforms/nangate45/cells_latch.v
# 10.2. Continuing TECHMAP pass.
# 11. Executing DFFLIBMAP pass (mapping DFF cells to sequential cells from liberty file).
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFRS_X1' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFRS_X2' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFR_X1' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFR_X2' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFS_X1' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFFS_X2' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFF_X1' - skipping.
# Warning: Found unsupported expression 'SE*SI+D*!SE' in pin attribute of cell 'SDFF_X2' - skipping.
# 11.1. Executing DFFLEGALIZE pass (convert FFs to types supported by the target).
# 12. Executing OPT pass (performing simple optimizations).
# 12.1. Executing OPT_EXPR pass (perform const folding).
# ...
#      2    4.00                           _036410_ (net)
#                   0.03    0.00    2.50 ^ _189079_/B1 (AOI21_X1)
#                   0.01    0.02    2.52 v _189079_/ZN (AOI21_X1)
#      1    2.43                           _036412_ (net)
#                   0.01    0.00    2.52 v _189081_/B1 (OAI21_X1)
#                   0.04    0.05    2.57 ^ _189081_/ZN (OAI21_X1)
#      2    6.07                           _036414_ (net)
#                   0.04    0.00    2.57 ^ _189084_/B1 (AOI21_X2)
#                   0.02    0.02    2.59 v _189084_/ZN (AOI21_X2)
#      2    6.37                           _036416_ (net)
#                   0.02    0.00    2.59 v _189098_/B2 (OAI21_X2)
#                   0.03    0.04    2.64 ^ _189098_/ZN (OAI21_X2)
#      2    6.73                           _036428_ (net)
#                   0.03    0.00    2.64 ^ _189099_/A (INV_X1)
#                   0.01    0.02    2.66 v _189099_/ZN (INV_X1)
#      2    5.82                           _064696_ (net)
#                   0.01    0.00    2.66 v _189102_/B1 (OAI21_X1)
#                   0.03    0.04    2.69 ^ _189102_/ZN (OAI21_X1)
#      1    3.76                           _036431_ (net)
#                   0.03    0.00    2.69 ^ _189103_/B1 (AOI21_X2)
#                   0.02    0.02    2.72 v _189103_/ZN (AOI21_X2)
#      2    5.85                           _064701_ (net)
#                   0.02    0.00    2.72 v _222585_/A (FA_X1)
#                   0.02    0.08    2.80 v _222585_/CO (FA_X1)
#      1    4.59                           _064704_ (net)
#                   0.02    0.00    2.80 v _189147_/B (XOR2_X2)
#                   0.02    0.06    2.86 v _189147_/Z (XOR2_X2)
#      2    6.22                           _036466_ (net)
#                   0.02    0.00    2.86 v _189148_/A2 (OR2_X1)
#                   0.01    0.06    2.92 v _189148_/ZN (OR2_X1)
#      1    3.68                           _036467_ (net)
#                   0.01    0.00    2.92 v _189149_/A4 (NOR4_X2)
#                   0.06    0.10    3.02 ^ _189149_/ZN (NOR4_X2)
#      3    6.93                           _115342_ (net)
#                   0.06    0.00    3.02 ^ _189153_/A2 (NAND4_X1)
#                   0.03    0.05    3.07 v _189153_/ZN (NAND4_X1)
#      2    4.06                           _036471_ (net)
#                   0.03    0.00    3.07 v _189155_/A2 (NOR3_X1)
#                   0.05    0.07    3.14 ^ _189155_/ZN (NOR3_X1)
#      2    4.47                           _115369_ (net)
#                   0.05    0.00    3.14 ^ _235109_/A (HA_X1)
#                   0.01    0.05    3.19 ^ _235109_/CO (HA_X1)
#      1    4.49                           _115371_ (net)
#                   0.01    0.00    3.19 ^ _189739_/A (XOR2_X2)
#                   0.04    0.07    3.26 ^ _189739_/Z (XOR2_X2)
#      3   11.69                           _036965_ (net)
#                   0.04    0.00    3.26 ^ _189741_/A1 (NAND2_X1)
#                   0.02    0.04    3.30 v _189741_/ZN (NAND2_X1)
#      2    7.20                           _036967_ (net)
#                   0.02    0.00    3.30 v _190325_/A3 (NOR3_X2)
#                   0.04    0.07    3.37 ^ _190325_/ZN (NOR3_X2)
#      2    6.67                           _037438_ (net)
#                   0.04    0.00    3.37 ^ _190326_/A (INV_X2)
#                   0.02    0.02    3.39 v _190326_/ZN (INV_X2)
#      3   15.77                           _037439_ (net)
#                   0.02    0.00    3.39 v _190327_/A4 (NOR4_X4)
#                   0.06    0.11    3.50 ^ _190327_/ZN (NOR4_X4)
#      4   14.51                           _037440_ (net)
#                   0.06    0.00    3.50 ^ _190328_/B1 (AOI21_X4)
#                   0.02    0.03    3.52 v _190328_/ZN (AOI21_X4)
#      4   10.93                           _037441_ (net)
#                   0.02    0.00    3.52 v _190374_/A (AOI21_X1)
#                   0.02    0.05    3.57 ^ _190374_/ZN (AOI21_X1)
#      1    2.25                           _037478_ (net)
#                   0.02    0.00    3.57 ^ _190375_/A (INV_X1)
#                   0.01    0.01    3.58 v _190375_/ZN (INV_X1)
#      1    1.74                           _037479_ (net)
#                   0.01    0.00    3.58 v _190376_/B2 (AOI21_X1)
#                   0.02    0.03    3.61 ^ _190376_/ZN (AOI21_X1)
#      1    2.01                           _037480_ (net)
#                   0.02    0.00    3.61 ^ _190378_/A (AOI21_X1)
#                   0.01    0.02    3.63 v _190378_/ZN (AOI21_X1)
#      1    1.78                           _main_kernel_i0.Datapath_i.__float_adde8m23b_127rnh_394_i2.Datapath_i.fu___float_adde8m23b_127rnh_497158_497766.out1[17] (net)
#                   0.01    0.00    3.63 v _206969_/D (DFF_X1)
#                                   3.63   data arrival time
#
#                           5.00    5.00   clock clock (rise edge)
#                           0.00    5.00   clock source latency
#                   0.00    0.00    5.00 ^ clock (in)
#      1   43.40                           clock (net)
#                   0.04    0.03    5.03 ^ repeater1/A (BUF_X8)
#                   0.01    0.03    5.06 ^ repeater1/Z (BUF_X8)
#      1   51.28                           net2286 (net)
#                   0.03    0.02    5.09 ^ clkbuf_0_clock/A (BUF_X4)
#                   0.01    0.03    5.12 ^ clkbuf_0_clock/Z (BUF_X4)
#      2   17.40                           clknet_0_clock (net)
#                   0.01    0.00    5.12 ^ clkbuf_1_1_0_clock/A (BUF_X4)
#                   0.02    0.03    5.15 ^ clkbuf_1_1_0_clock/Z (BUF_X4)
#      2   32.98                           clknet_1_1_0_clock (net)
#                   0.02    0.01    5.16 ^ clkbuf_2_3_0_clock/A (BUF_X4)
#                   0.02    0.04    5.20 ^ clkbuf_2_3_0_clock/Z (BUF_X4)
#      2   31.75                           clknet_2_3_0_clock (net)
#                   0.02    0.01    5.21 ^ clkbuf_3_6_0_clock/A (BUF_X4)
#                   0.01    0.03    5.24 ^ clkbuf_3_6_0_clock/Z (BUF_X4)
#      2   17.29                           clknet_3_6_0_clock (net)
#                   0.01    0.00    5.24 ^ clkbuf_4_12_0_clock/A (BUF_X4)
#                   0.02    0.03    5.27 ^ clkbuf_4_12_0_clock/Z (BUF_X4)
#      4   34.67                           clknet_4_12_0_clock (net)
#                   0.02    0.01    5.28 ^ clkbuf_6_49_0_clock/A (BUF_X4)
#                   0.04    0.06    5.34 ^ clkbuf_6_49_0_clock/Z (BUF_X4)
#      9   60.81                           clknet_6_49_0_clock (net)
#                   0.04    0.01    5.34 ^ clkbuf_opt_78_0_clock/A (BUF_X4)
#                   0.01    0.03    5.37 ^ clkbuf_opt_78_0_clock/Z (BUF_X4)
#      1   10.15                           clknet_opt_78_0_clock (net)
#                   0.01    0.00    5.37 ^ clkbuf_leaf_290_clock/A (BUF_X4)
#                   0.03    0.04    5.41 ^ clkbuf_leaf_290_clock/Z (BUF_X4)
#     30   41.84                           clknet_leaf_290_clock (net)
#                   0.03    0.00    5.42 ^ _206969_/CK (DFF_X1)
#                           0.00    5.42   clock reconvergence pessimism
#                          -0.03    5.38   library setup time
#                                   5.38   data required time
# -----------------------------------------------------------------------------
#                                   5.38   data required time
#                                  -3.63   data arrival time
# -----------------------------------------------------------------------------
#                                   1.76   slack (MET)
#
#
#
# ==========================================================================
# finish report_check_types -max_slew -max_cap -max_fanout -violators
# --------------------------------------------------------------------------
# max capacitance
#
# Pin                                    Limit     Cap   Slack
# ------------------------------------------------------------
# _211978_/Q                            121.15  134.07  -12.91 (VIOLATED)
# _212010_/Q                            121.15  131.15  -10.00 (VIOLATED)
# _211972_/Q                            121.15  130.30   -9.15 (VIOLATED)
# _197432_/ZN                            43.87   52.19   -8.32 (VIOLATED)
# _144808_/ZN                           101.01  108.51   -7.50 (VIOLATED)
# _202660_/ZN                           104.07  110.53   -6.47 (VIOLATED)
# _202714_/ZN                           106.81  113.27   -6.46 (VIOLATED)
# _239952_/S                             25.25   30.85   -5.60 (VIOLATED)
# _202466_/ZN                           237.43  242.92   -5.50 (VIOLATED)
# _207237_/Q                            121.15  126.61   -5.45 (VIOLATED)
# _198000_/ZN                           106.81  112.22   -5.41 (VIOLATED)
# _197975_/ZN                           106.81  111.91   -5.10 (VIOLATED)
# _208043_/Q                            121.15  125.70   -4.55 (VIOLATED)
# _193807_/ZN                            63.32   66.38   -3.06 (VIOLATED)
# _168530_/ZN                            27.62   30.43   -2.81 (VIOLATED)
# _207842_/Q                            121.15  123.96   -2.81 (VIOLATED)
# _199058_/ZN                            92.47   95.10   -2.63 (VIOLATED)
# _159337_/ZN                           106.81  109.26   -2.44 (VIOLATED)
# _159949_/ZN                           106.81  109.04   -2.23 (VIOLATED)
# _209198_/Q                            121.15  123.02   -1.87 (VIOLATED)
# _207844_/Q                            121.15  122.73   -1.57 (VIOLATED)
# _138713_/ZN                            52.03   53.27   -1.23 (VIOLATED)
# _241045_/CO                            60.58   61.78   -1.21 (VIOLATED)
# _237282_/S                             25.25   26.11   -0.86 (VIOLATED)
# _234966_/S                             25.25   25.88   -0.63 (VIOLATED)
# _197742_/ZN                            43.87   44.46   -0.59 (VIOLATED)
# _207952_/Q                            121.15  121.62   -0.46 (VIOLATED)
# _159107_/ZN                            11.48   11.91   -0.43 (VIOLATED)
# _234960_/S                             25.25   25.42   -0.17 (VIOLATED)
# _187560_/ZN                           101.01  101.09   -0.07 (VIOLATED)
# _202704_/ZN                            63.32   63.38   -0.06 (VIOLATED)
# _239953_/S                             25.25   25.28   -0.03 (VIOLATED)
#
#
# ==========================================================================
# finish max_slew_violation_count
# --------------------------------------------------------------------------
# max slew violation count 0
#
# ==========================================================================
# finish max_fanout_violation_count
# --------------------------------------------------------------------------
# max fanout violation count 0
#
# ==========================================================================
# finish max_cap_violation_count
# --------------------------------------------------------------------------
# max cap violation count 32
#
# ==========================================================================
# finish report_tns
# --------------------------------------------------------------------------
# tns 0.00
#
# ==========================================================================
# finish report_wns
# --------------------------------------------------------------------------
# wns 0.00
#
# ==========================================================================
# finish report_worst_slack
# --------------------------------------------------------------------------
# worst slack 1.76
#
# ==========================================================================
# finish report_clock_skew
# --------------------------------------------------------------------------
# Clock clock
# Latency      CRPR       Skew
# _209183_/CK ^
#    0.46
# _212351_/CK ^
#    0.36      0.00       0.10
#
#
# ==========================================================================
# finish report_power
# --------------------------------------------------------------------------
# Group                  Internal  Switching    Leakage      Total
#                           Power      Power      Power      Power
# ----------------------------------------------------------------
# Sequential             1.69e-02   3.01e-03   1.32e-03   2.12e-02  34.3%
# Combinational          1.56e-02   2.12e-02   3.77e-03   4.05e-02  65.7%
# Macro                  0.00e+00   0.00e+00   0.00e+00   0.00e+00   0.0%
# Pad                    0.00e+00   0.00e+00   0.00e+00   0.00e+00   0.0%
# ----------------------------------------------------------------
# Total                  3.25e-02   2.42e-02   5.09e-03   6.17e-02 100.0%
#                           52.6%      39.2%       8.2%
#
# ==========================================================================
# finish report_design_area
# --------------------------------------------------------------------------
# Design area 238968 u^2 16% utilization.
#
# [WARNING GUI-0010] File path does not end with a valid extension, new path is: /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/reports/nangate45/main_kernel/base/final.webp.png
# Elapsed time: 1:40.24[h:]min:sec. CPU time: user 98.41 sys 1.80 (99%). Peak memory: 2499820KB.
# cp /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/5_route.sdc /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.sdc
# sed '/OR_DEFAULT/d' /OpenROAD-flow-scripts/flow/platforms/nangate45/lef/NangateOpenCellLibrary.tech.lef > /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/klayout_tech.lef
# sed 's,<lef-files>.*</lef-files>,<lef-files>/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/klayout_tech.lef</lef-files> <lef-files>/OpenROAD-flow-scripts/flow/platforms/nangate45/lef/NangateOpenCellLibrary.macro.mod.lef</lef-files>,g' /OpenROAD-flow-scripts/flow/platforms/nangate45/FreePDK45.lyt > /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/klayout.lyt
# (/usr/bin/time -f 'Elapsed time: %E[h:]min:sec. CPU time: user %U sys %S (%P). Peak memory: %MKB.' stdbuf -o L /usr/bin/klayout -zz -rd design_name=main_kernel \
#         -rd in_def=/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.def \
#         -rd in_files="/OpenROAD-flow-scripts/flow/platforms/nangate45/gds/NangateOpenCellLibrary.gds  " \
#         -rd config_file= \
#         -rd seal_file="" \
#         -rd out_file=/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_1_merged.gds \
#         -rd tech_file=/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/objects/nangate45/main_kernel/base/klayout.lyt \
#         -rm /OpenROAD-flow-scripts/flow/util/def2stream.py) 2>&1 | tee /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base/6_1_merge.log
# [INFO] Reporting cells prior to loading DEF ...
# [INFO] Reading DEF ...
# [INFO] Clearing cells...
# [INFO] ... preserving 'VIA_via6_960x2800'
# [INFO] ... preserving 'VIA_via5_960x2800'
# [INFO] ... preserving 'VIA_via4_960x2800'
# [INFO] ... preserving 'VIA_via3_960x340'
# [INFO] ... preserving 'VIA_via2_960x340'
# [INFO] ... preserving 'VIA_via1_960x340'
# [INFO] ... preserving 'VIA_via1_4'
# [INFO] ... preserving 'VIA_via2_5'
# [INFO] ... preserving 'VIA_via1_7'
# [INFO] ... preserving 'VIA_via3_2'
# [INFO] ... preserving 'VIA_via4_0'
# [INFO] ... preserving 'VIA_via5_0'
# [INFO] ... preserving 'VIA_via6_0'
# [INFO] Merging GDS/OAS files...
# 	/OpenROAD-flow-scripts/flow/platforms/nangate45/gds/NangateOpenCellLibrary.gds
# [INFO] Copying toplevel cell 'main_kernel'
# WARNING: no fill config file specified
# [INFO] Checking for missing cell from GDS/OAS...
# [INFO] All LEF cells have matching GDS/OAS cells
# [INFO] Checking for orphan cell in the final layout...
# [INFO] No orphan cells
# [INFO] Writing out GDS/OAS '/Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_1_merged.gds'
# Elapsed time: 0:23.36[h:]min:sec. CPU time: user 22.56 sys 0.79 (99%). Peak memory: 1454848KB.
# cp /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_1_merged.gds /Panda-flow/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.gds
# /files0/extended/bohm747/Development/soda/soda-opt/docs/tutorials/date2022/docker-version

# %% [markdown]
# ## Comparison of synthesis results
#
# * Display area
# * Display power
# * Calculate and display FLOPS/W

# %%
log_path_suffix='HLS_output/Synthesis/bash_flow/openroad/logs/nangate45/main_kernel/base/6_report.log'
gds_path_suffix='HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.gds'

# %% [markdown]
# ### Baseline

# %%
baseline_log='output/baseline/'+log_path_suffix

# %%
power_multiplier = 1 # Open road reports power in mW

log_file=baseline_log
total_power = ()

for l in open(log_file, 'r').readlines():
  if ("Total" in l and "Group" not in l):
    total_power=float(l.split()[4])*power_multiplier

  if ("Design area" in l):
    available_area=float(l.split()[2])
    utilization_area=float(l.split()[4].strip('%'))
  

print('Baseline accelerator:')
print('  total power consumption: {}W'.format(total_power))
print('  available chip area: {} um^2'.format(available_area))
print('  utilized chip area: {}%'.format(utilization_area))


baseline_total_power=total_power
baseline_available_area=available_area
baseline_utilization_area=utilization_area
# Out:
# Baseline accelerator:
#   total power consumption: 0.00642W
#   available chip area: 28904.0 um^2
#   utilized chip area: 2.0%

# %% [markdown]
# ### Optimized for runtime

# %%
optimized_log='output/optimized/'+log_path_suffix

# %%
log_file=optimized_log
total_power = ()

for l in open(log_file, 'r').readlines():
  if ("Total" in l and "Group" not in l):
    total_power=float(l.split()[4])*power_multiplier

  if ("Design area" in l):
    available_area=float(l.split()[2])
    utilization_area=float(l.split()[4].strip('%'))
  

print('Optimized accelerator:')
print('  total power consumption: {}W'.format(total_power))
print('  available chip area: {} um^2'.format(available_area))
print('  utilized chip area: {}%'.format(utilization_area))

optimized_total_power=total_power
optimized_available_area=available_area
optimized_utilization_area=utilization_area
# Out:
# Optimized accelerator:
#   total power consumption: 0.0617W
#   available chip area: 238968.0 um^2
#   utilized chip area: 16.0%

# %% [markdown]
# ## Post place and route comparison
#
# Considering a matrix multiply kernel has approximatelly 2xNxMxK arithmetic operations
#
# And our selected kernel has the following sizes:
#
# ```
# linalg.batch_matmul ins(%23, %6 : memref<1x4x8xf32>, memref<1x8x4xf32>)
#                     outs(%25 : memref<1x4x4xf32>)
# ```
# M=4, K=8, N=4
#
# We have approximatelly **256** floating point aritihmetic operations

# %%
giga_multiplier=1e9
flop_count = 256 # arithmetic float point operations
target_frequency = 200e+6 # 200MHz

optimized_runtime_in_s = optimized_runtime/target_frequency
baseline_runtime_in_s = baseline_runtime/target_frequency 

baseline_flops_per_watt= flop_count/baseline_runtime_in_s/baseline_total_power
optimized_flops_per_watt= flop_count/optimized_runtime_in_s/optimized_total_power


print("Execution in cycles of Baseline kernel:  {}".format(baseline_runtime))
print("Execution in cycles of Optimized kernel:   {}".format(optimized_runtime))

print("Speedup: \t\t\t{:.2f}x".format(baseline_runtime/optimized_runtime))
print("Area utilization overhead: \t {:.2f}x".format(optimized_utilization_area/baseline_utilization_area))
print("Power overhead: \t\t {:.2f}x".format(optimized_total_power/baseline_total_power))

print("Baseline  \t\t\t {:.2f} GFLOPS/W ".format(baseline_flops_per_watt/giga_multiplier))
print("Optimized \t\t\t{:.2f} GFLOPS/W".format(optimized_flops_per_watt/giga_multiplier))
# Out:
# Execution in cycles of Baseline kernel:  1158
# Execution in cycles of Optimized kernel:   55
# Speedup: 			21.05x
# Area utilization overhead: 	 8.00x
# Power overhead: 		 9.61x
# Baseline  			 6.89 GFLOPS/W
# Optimized 			15.09 GFLOPS/W

# %% [markdown]
# ## Generated GDSII files
#
# Output files can be found here:
#
# * output/baseline/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.gds
# * output/optimized/HLS_output/Synthesis/bash_flow/openroad/results/nangate45/main_kernel/base/6_final.gds

# %% [markdown]
# ### Baseline and Optimized Side by Side
#
# <p float="middle">
#   <img src="imgs/baseline_view.png" width="49%" />
#   <img src="imgs/optimized_view.png" width="49%" />
# </p>

# %% [markdown]
# # Thank you!
